# %% [markdown]
# # Discharge Notes and Readmission Rates: EDA

# %% [markdown]
# This notebook is for the initial exploratory data analysis of the dataset. Readmission is defined as anyone who was readmitted, unplanned, within 30 days of discharge from the last admissions. Please see the following for the other notebooks:
# * [NLP Modeling Notebook](02_Modeling_NLP.ipynb)
# * [Modeling with Additional Featuers](03_Modeling_Additional_Features)

# %% [markdown]
# ## Import

# %% [markdown]
# Import all the relevant libraries.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression
#nlp libraries 
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer 
from nltk.stem.porter import PorterStemmer
import string

#vectorizers
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.corpus import stopwords

# %% [markdown]
# ## Overview

# %% [markdown]
# Hospital readmissions are costly for health systems and payers. The average readmission cost in 2016 was $14.4K. That is why one of the metrics payers use to assess healthcare systems and medical providers is 30-day readmission rates. The Centers for Medicare & Medicaid Services (CMS) has implemented the [Hospital Readmissions Reduction Program](https://www.cms.gov/Medicare/Medicare-Fee-for-Service-Payment/AcuteInpatientPPS/Readmissions-Reduction-Program) (HRRP), which incentivizes providers by tying reimbursements with readmission rates. However, according to the [Agency for Healthcare Research and Quality (AHRQ)](https://www.hcup-us.ahrq.gov/reports/statbriefs/sb248-Hospital-Readmissions-2010-2016.jsp), readmission rates in the US has stayed relatively consistent from 2010 to 2016, as see in the figure below. Based on a [study](https://jamanetwork.com/journals/jamainternalmedicine/fullarticle/2498846) conducted by the University of California San Francisco (UCSF), approximately 27% of 30-day readmissions are preventable.

# %%
#data from AHRQ, link in text above
X = [2010, 2011, 2012, 2013, 2014, 2015, 2016]

readmission = [14.2, 14.3, 14.1, 13.9, 13.9, 14.0, 13.9]

# %%
#create a figure
fig, ax = plt.subplots(figsize=(8,8))
#set background color to white
fig.patch.set_facecolor('white')
#create a bar graph
ax.plot(X, readmission, color='royalblue')
#set the title and axis label
ax.set_title('30-Day Readmission Rates, 2010-2016',fontsize=14)
ax.set_ylabel("30-Day Readmission Rates (%)", fontsize=12)
ax.set_ylim(bottom=10, top=15)

for i in range(len(X)):
    ax.annotate(str(readmission[i])+"%", xy=(X[i]-0.1, readmission[i]+0.1))
plt.tight_layout()
plt.show()

#save the figure in the images folder
fig.savefig('images/30_day_readmissions.png', bbox_inches='tight')

# %% [markdown]
# ## Business Understanding

# %% [markdown]
# ## Data Understanding

# %% [markdown]
# ## Functions

# %% [markdown]
# This section is for any functions created for the analysis.

# %%
def group_categories(df, category):
    '''
    some of the datasets have multiple rows for diagnosis or ICD code per subject and admission ID
    in order to onehotencode it later, this function aggregates all the codes into a list, and then
    convert the list into a string separate by a comma
    
    the function takes in the dataframe which should only contain three columns: subject_id, hadm_id,
    and the category of interest; and the string for the column name of the cateogry of interest
    '''
    #group by the subject and admission ID
    group = df.groupby(['SUBJECT_ID', 'HADM_ID'])
    #create a list of all the values associated with the subject and admission ID
    result = group.agg({category:lambda x:list(set(x.tolist()))})
    result.reset_index(inplace=True)
    #convert the list into a string, separated by commas
    result[category] = [', '.join(map(str, l)) for l in result[category]]
    return result

# %%
stemmer = PorterStemmer()
def stem_text(text):
    '''
    This function takes a text and stem it
    '''
    return [stemmer.stem(w) for w in word_tokenize(text)]

# %%
lemmatizer = WordNetLemmatizer()
def lemmatize_text(token_text):
    '''
    This function takes an already tokenized text and lemmatize it
    '''
    return [lemmatizer.lemmatize(w) for w in token_text]

# %% [markdown]
# The two functions below were derived from [Insight Data Science](https://blog.insightdatascience.com/how-to-solve-90-of-nlp-problems-a-step-by-step-guide-fda605278e4e). It finds the importance of the words using a vectorizer and model, and then plotting the importance as bar graphs.

# %%
def get_most_important_features(vectorizer, model, n=5):
    '''
    This function takes in a vectorizer and a model, preferably logistic regression,
    and returns a dictionary of words and their coefficients of the top n and bottom
    n words
    '''
    index_to_word = {v:k for k,v in vectorizer.vocabulary_.items()}
    
    # loop for each class
    classes ={}
    for class_index in range(model.coef_.shape[0]):
        word_importances = [(el, index_to_word[i]) for i,el in enumerate(model.coef_[class_index])]
        sorted_coeff = sorted(word_importances, key = lambda x : x[0], reverse=True)
        tops = sorted(sorted_coeff[:n], key = lambda x : x[0])
        bottom = sorted_coeff[-n:]
        classes[class_index] = {
            'tops':tops,
            'bottom':bottom
        }
    return classes

# %%
def plot_important_words(top_scores, top_words, bottom_scores, bottom_words, name):
    '''
    this function plots the top and bottom words based on importance as bar graphs
    '''
    y_pos = np.arange(len(top_words))
    top_pairs = [(a,b) for a,b in zip(top_words, top_scores)]
    top_pairs = sorted(top_pairs, key=lambda x: x[1])
    
    bottom_pairs = [(a,b) for a,b in zip(bottom_words, bottom_scores)]
    bottom_pairs = sorted(bottom_pairs, key=lambda x: x[1], reverse=True)
    
    top_words = [a[0] for a in top_pairs]
    top_scores = [a[1] for a in top_pairs]
    
    bottom_words = [a[0] for a in bottom_pairs]
    bottom_scores = [a[1] for a in bottom_pairs]
    
    fig = plt.figure(figsize=(10, 10))
    fig.patch.set_facecolor('white')

    plt.subplot(121)
    plt.barh(y_pos,bottom_scores, align='center', alpha=0.5)
    plt.title('Irrelevant', fontsize=20)
    plt.yticks(y_pos, bottom_words, fontsize=14)
    plt.suptitle('Key words', fontsize=16)
    plt.xlabel('Importance', fontsize=20)
    
    plt.subplot(122)
    plt.barh(y_pos,top_scores, align='center', alpha=0.5)
    plt.title('Readmission', fontsize=20)
    plt.yticks(y_pos, top_words, fontsize=14)
    plt.suptitle(name, fontsize=16)
    plt.xlabel('Importance', fontsize=20)
    
    plt.subplots_adjust(wspace=0.8)
    plt.show()
    return fig

# %% [markdown]
# ## Exploratory Data Analysis (EDA)

# %% [markdown]
# In this section, I focused on reviewing the datasets I am using for this project.

# %% [markdown]
# ### Admission Data

# %% [markdown]
# The ADMISSIONS.csv contains patient demographic information for each patient represented by 'SUBJECT_ID' and each admission represented by 'HADM_ID'.

# %% [markdown]
# The ADMISSIONS dataset has the information on the demographics of the patient.

# %%
#read in the dataset
admit_df = pd.read_csv('data/ADMISSIONS.csv.gz', compression='gzip')

# %%
#review the columns in the dataset
admit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58976 entries, 0 to 58975
# Data columns (total 19 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID                58976 non-null  int64
#  1   SUBJECT_ID            58976 non-null  int64
#  2   HADM_ID               58976 non-null  int64
#  3   ADMITTIME             58976 non-null  object
#  4   DISCHTIME             58976 non-null  object
#  5   DEATHTIME             5854 non-null   object
#  6   ADMISSION_TYPE        58976 non-null  object
#  7   ADMISSION_LOCATION    58976 non-null  object
#  8   DISCHARGE_LOCATION    58976 non-null  object
#  9   INSURANCE             58976 non-null  object
#  10  LANGUAGE              33644 non-null  object
#  11  RELIGION              58518 non-null  object
#  12  MARITAL_STATUS        48848 non-null  object
#  13  ETHNICITY             58976 non-null  object
#  14  EDREGTIME             30877 non-null  object
#  15  EDOUTTIME             30877 non-null  object
#  16  DIAGNOSIS             58951 non-null  object
#  17  HOSPITAL_EXPIRE_FLAG  58976 non-null  int64
#  18  HAS_CHARTEVENTS_DATA  58976 non-null  int64
# dtypes: int64(5), object(14)
# memory usage: 8.5+ MB

# %%
#review the first 5 entires in the dataset
admit_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID            ADMITTIME            DISCHTIME  \
# 0      21          22   165315  2196-04-09 12:26:00  2196-04-10 15:54:00
# 1      22          23   152223  2153-09-03 07:15:00  2153-09-08 19:10:00
# 2      23          23   124321  2157-10-18 19:34:00  2157-10-25 14:00:00
# 3      24          24   161859  2139-06-06 16:14:00  2139-06-09 12:48:00
# 4      25          25   129635  2160-11-02 02:06:00  2160-11-05 14:55:00
#
#   DEATHTIME ADMISSION_TYPE         ADMISSION_LOCATION  \
# 0       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
# 1       NaN       ELECTIVE  PHYS REFERRAL/NORMAL DELI
# 2       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 3       NaN      EMERGENCY  TRANSFER FROM HOSP/EXTRAM
# 4       NaN      EMERGENCY       EMERGENCY ROOM ADMIT
#
#           DISCHARGE_LOCATION INSURANCE LANGUAGE           RELIGION  \
# 0  DISC-TRAN CANCER/CHLDRN H   Private      NaN       UNOBTAINABLE
# 1           HOME HEALTH CARE  Medicare      NaN           CATHOLIC
# 2           HOME HEALTH CARE  Medicare     ENGL           CATHOLIC
# 3                       HOME   Private      NaN  PROTESTANT QUAKER
# 4                       HOME   Private      NaN       UNOBTAINABLE
#
#   MARITAL_STATUS ETHNICITY            EDREGTIME            EDOUTTIME  \
# 0        MARRIED     WHITE  2196-04-09 10:06:00  2196-04-09 13:24:00
# 1        MARRIED     WHITE                  NaN                  NaN
# 2        MARRIED     WHITE                  NaN                  NaN
# 3         SINGLE     WHITE                  NaN                  NaN
# 4        MARRIED     WHITE  2160-11-02 01:01:00  2160-11-02 04:27:00
#
#                                            DIAGNOSIS  HOSPITAL_EXPIRE_FLAG  \
# 0                            BENZODIAZEPINE OVERDOSE                     0
# 1  CORONARY ARTERY DISEASE\CORONARY ARTERY BYPASS...                     0
# 2                                         BRAIN MASS                     0
# 3                     INTERIOR MYOCARDIAL INFARCTION                     0
# 4                            ACUTE CORONARY SYNDROME                     0
#
#    HAS_CHARTEVENTS_DATA
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1

# %%
#check what admission types are included
admit_df['ADMISSION_TYPE'].value_counts()
# Out:
# EMERGENCY    42071
# NEWBORN       7863
# ELECTIVE      7706
# URGENT        1336
# Name: ADMISSION_TYPE, dtype: int64

# %%
#drop any irrelevant columns
columns_to_drop = ['DEATHTIME','EDREGTIME','EDOUTTIME','HOSPITAL_EXPIRE_FLAG']
admit_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
#check how many unique patients
admit_df['SUBJECT_ID'].nunique()
# Out:
# 46520

# %% [markdown]
# ### Chart Notes

# %% [markdown]
# The NOTEEVENTS.csv contains the chart notes of each patient and admission.

# %% [markdown]
# The NOTEEVENTS dataset has the chart notes, including discharge notes, per patient and admissions.

# %%
#read in the dataset
notes_df = pd.read_csv('data/NOTEEVENTS.csv.gz', compression='gzip')
# Out:
# /Users/arthur/opt/anaconda3/envs/main_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#review the columns in the dataset
notes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2083180 entries, 0 to 2083179
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   ROW_ID       int64
#  1   SUBJECT_ID   int64
#  2   HADM_ID      float64
#  3   CHARTDATE    object
#  4   CHARTTIME    object
#  5   STORETIME    object
#  6   CATEGORY     object
#  7   DESCRIPTION  object
#  8   CGID         float64
#  9   ISERROR      float64
#  10  TEXT         object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 174.8+ MB

# %%
#review the first 5 entires in the dataset
notes_df.head()
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME  \
# 0     174       22532  167853.0  2151-08-04       NaN       NaN
# 1     175       13702  107527.0  2118-06-14       NaN       NaN
# 2     176       13702  167118.0  2119-05-25       NaN       NaN
# 3     177       13702  196489.0  2124-08-18       NaN       NaN
# 4     178       26880  135453.0  2162-03-25       NaN       NaN
#
#             CATEGORY DESCRIPTION  CGID  ISERROR  \
# 0  Discharge summary      Report   NaN      NaN
# 1  Discharge summary      Report   NaN      NaN
# 2  Discharge summary      Report   NaN      NaN
# 3  Discharge summary      Report   NaN      NaN
# 4  Discharge summary      Report   NaN      NaN
#
#                                                 TEXT
# 0  Admission Date:  [**2151-7-16**]       Dischar...
# 1  Admission Date:  [**2118-6-2**]       Discharg...
# 2  Admission Date:  [**2119-5-4**]              D...
# 3  Admission Date:  [**2124-7-21**]              ...
# 4  Admission Date:  [**2162-3-3**]              D...

# %%
notes_df['CATEGORY'].value_counts()
# Out:
# Nursing/other        822497
# Radiology            522279
# Nursing              223556
# ECG                  209051
# Physician            141624
# Discharge summary     59652
# Echo                  45794
# Respiratory           31739
# Nutrition              9418
# General                8301
# Rehab Services         5431
# Social Work            2670
# Case Management         967
# Pharmacy                103
# Consult                  98
# Name: CATEGORY, dtype: int64

# %%
#the column ISERROR, if the value is 1, indicates that a physician indicated that the notes are wrong
#drop any columns that do not have an error
notes_df = notes_df[notes_df['ISERROR'] != 1]
#isolate the discharge notes
notes_df = notes_df[notes_df['CATEGORY'] == 'Discharge summary']

# %%
#drop any irrelevant columns
columns_to_drop = ['ROW_ID','CHARTDATE','CHARTTIME','STORETIME','CATEGORY','DESCRIPTION','CGID','ISERROR']
notes_df.drop(columns_to_drop, axis=1, inplace=True)

# %%
#review the edited dataframe
notes_df.head()
# Out:
#    SUBJECT_ID   HADM_ID                                               TEXT
# 0       22532  167853.0  Admission Date:  [**2151-7-16**]       Dischar...
# 1       13702  107527.0  Admission Date:  [**2118-6-2**]       Discharg...
# 2       13702  167118.0  Admission Date:  [**2119-5-4**]              D...
# 3       13702  196489.0  Admission Date:  [**2124-7-21**]              ...
# 4       26880  135453.0  Admission Date:  [**2162-3-3**]              D...

# %%
notes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 59652 entries, 0 to 60415
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   SUBJECT_ID  59652 non-null  int64
#  1   HADM_ID     59652 non-null  float64
#  2   TEXT        59652 non-null  object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.8+ MB

# %%
#it seems like there are multiple discharge notes per subject and admission IDs
notes_df.duplicated(subset=['SUBJECT_ID','HADM_ID'], keep=False)
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 60411     True
# 60412     True
# 60413     True
# 60414     True
# 60415     True
# Length: 59652, dtype: bool

# %%
#combine any texts that have the same SUBJECT_ID and HADM_ID
notes_df = group_categories(notes_df, 'TEXT')

# %%
notes_df
# Out:
#        SUBJECT_ID   HADM_ID                                               TEXT
# 0               3  145834.0  Admission Date:  [**2101-10-20**]     Discharg...
# 1               4  185777.0  Admission Date:  [**2191-3-16**]     Discharge...
# 2               6  107064.0  Admission Date: [**2175-5-30**]        Dischar...
# 3               9  150750.0  Admission Date:  [**2149-11-9**]       Dischar...
# 4              10  184167.0  Admission Date:  [**2103-6-28**]       Dischar...
# ...           ...       ...                                                ...
# 52721       99985  176670.0  Admission Date:  [**2181-1-27**]              ...
# 52722       99991  151118.0  Admission Date:  [**2184-12-24**]             ...
# 52723       99992  197084.0  Admission Date:  [**2144-7-25**]              ...
# 52724       99995  137810.0  Admission Date:  [**2147-2-8**]              D...
# 52725       99999  113369.0  Admission Date:  [**2117-12-30**]             ...
#
# [52726 rows x 3 columns]

# %% [markdown]
# ### Additional Patient Data

# %% [markdown]
# The PATIENTS.csv contains information on the patient's gender and date of birth (DOB).

# %% [markdown]
# The PATIENT dataset contains further information of the patient include date of birth and gender

# %%
#read in the dataset
patients_df = pd.read_csv('data/PATIENTS.csv.gz', compression='gzip')

# %%
#review the columns in the dataset
patients_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46520 entries, 0 to 46519
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   ROW_ID       46520 non-null  int64
#  1   SUBJECT_ID   46520 non-null  int64
#  2   GENDER       46520 non-null  object
#  3   DOB          46520 non-null  object
#  4   DOD          15759 non-null  object
#  5   DOD_HOSP     9974 non-null   object
#  6   DOD_SSN      13378 non-null  object
#  7   EXPIRE_FLAG  46520 non-null  int64
# dtypes: int64(3), object(5)
# memory usage: 2.8+ MB

# %%
#review the first 5 entires in the dataset
patients_df.head()
# Out:
#    ROW_ID  SUBJECT_ID GENDER                  DOB                  DOD  \
# 0     234         249      F  2075-03-13 00:00:00                  NaN
# 1     235         250      F  2164-12-27 00:00:00  2188-11-22 00:00:00
# 2     236         251      M  2090-03-15 00:00:00                  NaN
# 3     237         252      M  2078-03-06 00:00:00                  NaN
# 4     238         253      F  2089-11-26 00:00:00                  NaN
#
#               DOD_HOSP DOD_SSN  EXPIRE_FLAG
# 0                  NaN     NaN            0
# 1  2188-11-22 00:00:00     NaN            1
# 2                  NaN     NaN            0
# 3                  NaN     NaN            0
# 4                  NaN     NaN            0

# %%
#isolate the relevant columns
patients_df = patients_df[['SUBJECT_ID', 'GENDER', 'DOB']]

# %% [markdown]
# ### CPT Codes

# %% [markdown]
# The CPTEVENTS contains data on procedures recorded as Current Procedural Terminology (CPT) codes.

# %% [markdown]
# The CPTEVENTS dataset contains the CPT (Current Procedural Terminology ) codes are five digit number assigned to every service a medical practitioner provided to a patient.

# %%
#read in the dataset
cpt_events_df = pd.read_csv('data/CPTEVENTS.csv.gz', compression='gzip')
# Out:
# /Users/arthur/opt/anaconda3/envs/main_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (4,5,7,11) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
#review the columns in the dataset
cpt_events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 573146 entries, 0 to 573145
# Data columns (total 12 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   ROW_ID            573146 non-null  int64
#  1   SUBJECT_ID        573146 non-null  int64
#  2   HADM_ID           573146 non-null  int64
#  3   COSTCENTER        573146 non-null  object
#  4   CHARTDATE         101545 non-null  object
#  5   CPT_CD            573146 non-null  object
#  6   CPT_NUMBER        573128 non-null  float64
#  7   CPT_SUFFIX        22 non-null      object
#  8   TICKET_ID_SEQ     471601 non-null  float64
#  9   SECTIONHEADER     573125 non-null  object
#  10  SUBSECTIONHEADER  573125 non-null  object
#  11  DESCRIPTION       101545 non-null  object
# dtypes: float64(2), int64(3), object(7)
# memory usage: 52.5+ MB

# %%
#review the first 5 entires in the dataset
cpt_events_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID COSTCENTER CHARTDATE CPT_CD  CPT_NUMBER  \
# 0     317       11743   129545        ICU       NaN  99232     99232.0
# 1     318       11743   129545        ICU       NaN  99232     99232.0
# 2     319       11743   129545        ICU       NaN  99232     99232.0
# 3     320       11743   129545        ICU       NaN  99232     99232.0
# 4     321        6185   183725        ICU       NaN  99223     99223.0
#
#   CPT_SUFFIX  TICKET_ID_SEQ              SECTIONHEADER  \
# 0        NaN            6.0  Evaluation and management
# 1        NaN            7.0  Evaluation and management
# 2        NaN            8.0  Evaluation and management
# 3        NaN            9.0  Evaluation and management
# 4        NaN            1.0  Evaluation and management
#
#               SUBSECTIONHEADER DESCRIPTION
# 0  Hospital inpatient services         NaN
# 1  Hospital inpatient services         NaN
# 2  Hospital inpatient services         NaN
# 3  Hospital inpatient services         NaN
# 4  Hospital inpatient services         NaN

# %%
#isolate the relevant columns
cpt_events_df = cpt_events_df[['SUBJECT_ID', 'HADM_ID', 'CPT_CD']]

# %% [markdown]
# ### Diagnosis ICD Codes

# %% [markdown]
# The DIAGNOSES dataset contains all diagnoses per subject and admission IDs. The column SEQ_NUM contains the order in which the ICD diagnoses relate to the patient.

# %%
#read in the dataset
diagnoses_icd_df = pd.read_csv('data/DIAGNOSES_ICD.csv.gz', compression='gzip')

# %%
#review the columns in the dataset
diagnoses_icd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651047 entries, 0 to 651046
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ROW_ID      651047 non-null  int64
#  1   SUBJECT_ID  651047 non-null  int64
#  2   HADM_ID     651047 non-null  int64
#  3   SEQ_NUM     651000 non-null  float64
#  4   ICD9_CODE   651000 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 24.8+ MB

# %%
#review the first 5 entires in the dataset
diagnoses_icd_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254

# %%
#isolate the relevant columns
diagnoses_icd_df = diagnoses_icd_df[['SUBJECT_ID', 'HADM_ID', 'ICD9_CODE']]

# %% [markdown]
# ### DRG Codes

# %% [markdown]
# The DRGCODES contains the DRG (diagnosis-related group) codes, which is a patient classification system that standardizes prospective payment.

# %%
#read in the dataset
drg_codes_df = pd.read_csv('data/DRGCODES.csv.gz', compression='gzip')

# %%
#review the columns in the dataset
drg_codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125557 entries, 0 to 125556
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ROW_ID         125557 non-null  int64
#  1   SUBJECT_ID     125557 non-null  int64
#  2   HADM_ID        125557 non-null  int64
#  3   DRG_TYPE       125557 non-null  object
#  4   DRG_CODE       125557 non-null  int64
#  5   DESCRIPTION    125494 non-null  object
#  6   DRG_SEVERITY   66634 non-null   float64
#  7   DRG_MORTALITY  66634 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.7+ MB

# %%
#review the first 5 entires in the dataset
drg_codes_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID DRG_TYPE  DRG_CODE  \
# 0     342        2491   144486     HCFA        28
# 1     343       24958   162910     HCFA       110
# 2     344       18325   153751     HCFA       390
# 3     345       17887   182692     HCFA        14
# 4     346       11113   157980     HCFA       390
#
#                                          DESCRIPTION  DRG_SEVERITY  \
# 0  TRAUMATIC STUPOR & COMA, COMA <1 HR AGE >17 WI...           NaN
# 1  MAJOR CARDIOVASCULAR PROCEDURES WITH COMPLICAT...           NaN
# 2            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
# 3  SPECIFIC CEREBROVASCULAR DISORDERS EXCEPT TRAN...           NaN
# 4            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
#
#    DRG_MORTALITY
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN

# %%
#isolate the relevant columns
drg_codes_df = drg_codes_df[['SUBJECT_ID','HADM_ID','DRG_CODE']]

# %% [markdown]
# ### Procedure ICD Codes

# %% [markdown]
# The PROCEDURES_ICD dataset contains the procedure ICD codes per subject and patient IDs.

# %%
#read in the dataset
proced_icd_df = pd.read_csv('data/PROCEDURES_ICD.csv.gz', compression='gzip')

# %%
#review the columns in the dataset
proced_icd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240095 entries, 0 to 240094
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ROW_ID      240095 non-null  int64
#  1   SUBJECT_ID  240095 non-null  int64
#  2   HADM_ID     240095 non-null  int64
#  3   SEQ_NUM     240095 non-null  int64
#  4   ICD9_CODE   240095 non-null  int64
# dtypes: int64(5)
# memory usage: 9.2 MB

# %%
#review the first 5 entires in the dataset
proced_icd_df.head()
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0     944       62641   154460        3       3404
# 1     945        2592   130856        1       9671
# 2     946        2592   130856        2       3893
# 3     947       55357   119355        1       9672
# 4     948       55357   119355        2        331

# %%
#isolate the relevant columns
proced_icd_df = proced_icd_df[['SUBJECT_ID','HADM_ID','ICD9_CODE']]

# %% [markdown]
# ## Searching for 30-Day Readmissions that Were Emergencies

# %% [markdown]
# Here I manipulate the data to find which admissions led to a readmission that was unplanned within 30 days post discharge.

# %%
#sort the dates in ascending order, so that if we were to delete the last duplicate, it would be the latest admissions
admit_df.sort_values('ADMITTIME', inplace=True)
admit_df.reset_index(drop=True, inplace=True)

# %%
#convert the admission and discharge time to datetime objects
admit_df['ADMITTIME'] = admit_df['ADMITTIME'].str[:10]
admit_df['ADMITTIME'] = pd.to_datetime(admit_df['ADMITTIME'], format="%Y/%m/%d")
admit_df['DISCHTIME'] = admit_df['DISCHTIME'].str[:10]
admit_df['DISCHTIME'] = pd.to_datetime(admit_df['DISCHTIME'], format="%Y/%m/%d")

# %%
#create a new column of readmission date and type by shifting one over
admit_df['READMITTIME'] = admit_df.groupby('SUBJECT_ID')['ADMITTIME'].shift(-1)
admit_df['READMIT_TYPE'] = admit_df.groupby('SUBJECT_ID')['ADMISSION_TYPE'].shift(-1)

# %%
#review readmissions that were elective
admit_df[admit_df['READMIT_TYPE'] == 'ELECTIVE']
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 7       11401        9319   137275 2100-07-01 2100-07-15       ELECTIVE
# 109     52466       79576   195819 2100-09-18 2100-09-20      EMERGENCY
# 165     16723       13636   155423 2100-10-30 2100-11-03      EMERGENCY
# 167     43522       51754   105236 2100-10-31 2100-11-03      EMERGENCY
# 309     33507       27414   111607 2101-02-14 2101-02-15       ELECTIVE
# ...       ...         ...      ...        ...        ...            ...
# 58668   50668       73946   100104 2201-06-21 2201-07-03      EMERGENCY
# 58698   22286       18250   132130 2201-07-29 2201-09-04       ELECTIVE
# 58764   12401       10144   172618 2202-06-04 2202-06-05      EMERGENCY
# 58820    5933        4900   117413 2203-06-29 2203-07-08       ELECTIVE
# 58924   32919       26928   190130 2205-08-24 2205-08-27      EMERGENCY
#
#               ADMISSION_LOCATION        DISCHARGE_LOCATION   INSURANCE  \
# 7      PHYS REFERRAL/NORMAL DELI          HOME HEALTH CARE    Medicare
# 109    CLINIC REFERRAL/PREMATURE                      HOME     Private
# 165         EMERGENCY ROOM ADMIT                      HOME    Medicare
# 167    CLINIC REFERRAL/PREMATURE                      HOME     Private
# 309    PHYS REFERRAL/NORMAL DELI                      HOME     Private
# ...                          ...                       ...         ...
# 58668  TRANSFER FROM HOSP/EXTRAM          HOME HEALTH CARE  Government
# 58698  PHYS REFERRAL/NORMAL DELI                       SNF    Medicare
# 58764       EMERGENCY ROOM ADMIT                      HOME     Private
# 58820  PHYS REFERRAL/NORMAL DELI  REHAB/DISTINCT PART HOSP    Medicare
# 58924       EMERGENCY ROOM ADMIT          HOME HEALTH CARE    Medicare
#
#       LANGUAGE           RELIGION MARITAL_STATUS               ETHNICITY  \
# 7         ENGL  PROTESTANT QUAKER        WIDOWED                   WHITE
# 109       ENGL  PROTESTANT QUAKER        MARRIED                   WHITE
# 165       ENGL             JEWISH        WIDOWED                   WHITE
# 167       ENGL      NOT SPECIFIED        MARRIED                   WHITE
# 309       ENGL       UNOBTAINABLE        MARRIED  WHITE - OTHER EUROPEAN
# ...        ...                ...            ...                     ...
# 58668     ENGL      NOT SPECIFIED         SINGLE                   OTHER
# 58698     ENGL  PROTESTANT QUAKER         SINGLE  BLACK/AFRICAN AMERICAN
# 58764     ENGL           CATHOLIC        MARRIED                   WHITE
# 58820     ENGL  PROTESTANT QUAKER        MARRIED  BLACK/AFRICAN AMERICAN
# 58924     ENGL             JEWISH        MARRIED                   WHITE
#
#                              DIAGNOSIS  HAS_CHARTEVENTS_DATA READMITTIME  \
# 7                    LEFT RENAL CA/SDA                     1  2102-03-13
# 109                    DYSPNEA;S/P EGD                     1  2100-11-05
# 165             GASTROINTESTINAL BLEED                     1  2105-07-01
# 167                     LOWER GI BLEED                     1  2100-12-22
# 309      POPLITEAL ANEURYSM, RIGHT/SDA                     0  2101-02-28
# ...                                ...                   ...         ...
# 58668                 PERFORATED BOWEL                     1  2201-10-22
# 58698  CENTRAL NERVOUS SYSTEM LYMPHOMA                     1  2201-09-09
# 58764          ESOPHAGEAL FOREIGN BODY                     1  2202-10-11
# 58820                RECTAL CANCER/SDA                     1  2203-10-26
# 58924          ACUTE CORONARY SYNDROME                     1  2205-10-08
#
#       READMIT_TYPE
# 7         ELECTIVE
# 109       ELECTIVE
# 165       ELECTIVE
# 167       ELECTIVE
# 309       ELECTIVE
# ...            ...
# 58668     ELECTIVE
# 58698     ELECTIVE
# 58764     ELECTIVE
# 58820     ELECTIVE
# 58924     ELECTIVE
#
# [1407 rows x 17 columns]

# %%
#find which readmission were elective (planned) and at those indexes, set the readmit time and type
#to null
elective_index = admit_df['READMIT_TYPE'] == 'ELECTIVE'
admit_df.loc[elective_index,'READMITTIME'] = pd.NaT
admit_df.loc[elective_index,'READMIT_TYPE'] = np.NaN

# %%
#backfill the readmission time and type after deleting the elective ones to see when the
#next unplanned readmit was
admit_df['READMITTIME'] = admit_df.groupby(['SUBJECT_ID'])['READMITTIME'].fillna(method = 'bfill')
admit_df['READMIT_TYPE'] = admit_df.groupby(['SUBJECT_ID'])['READMIT_TYPE'].fillna(method = 'bfill')

# %%
#convert the discharge time and the readmission time to time series
ts_disch = admit_df['DISCHTIME'].dt.to_pydatetime()
ts_readmit = admit_df['READMITTIME'].dt.to_pydatetime()

# %%
#subtract the readmission time by the discharge time to get days between discharge and
#unplanned readmission
readmit_df = pd.DataFrame((ts_readmit-ts_disch))

# %%
readmit_df.head(10)
# Out:
#          0
# 0      NaT
# 1      NaT
# 2      NaT
# 3      NaT
# 4      NaT
# 5 254 days
# 6 590 days
# 7      NaT
# 8  91 days
# 9      NaT

# %%
#obtain the days
admit_df['DAYS_READMIT'] = readmit_df[0].dt.days

# %%
admit_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58976 entries, 0 to 58975
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID                58976 non-null  int64
#  1   SUBJECT_ID            58976 non-null  int64
#  2   HADM_ID               58976 non-null  int64
#  3   ADMITTIME             58976 non-null  datetime64[ns]
#  4   DISCHTIME             58976 non-null  datetime64[ns]
#  5   ADMISSION_TYPE        58976 non-null  object
#  6   ADMISSION_LOCATION    58976 non-null  object
#  7   DISCHARGE_LOCATION    58976 non-null  object
#  8   INSURANCE             58976 non-null  object
#  9   LANGUAGE              33644 non-null  object
#  10  RELIGION              58518 non-null  object
#  11  MARITAL_STATUS        48848 non-null  object
#  12  ETHNICITY             58976 non-null  object
#  13  DIAGNOSIS             58951 non-null  object
#  14  HAS_CHARTEVENTS_DATA  58976 non-null  int64
#  15  READMITTIME           11399 non-null  datetime64[ns]
#  16  READMIT_TYPE          11399 non-null  object
#  17  DAYS_READMIT          11399 non-null  float64
# dtypes: datetime64[ns](3), float64(1), int64(4), object(10)
# memory usage: 8.1+ MB

# %%
#any blanks we assume they were not readmitted, so for simplicity sake lets fill it with a
#number >30, since we are classifying the positive case as readmit days <30
admit_df['DAYS_READMIT'].fillna(1000,inplace=True)

# %%
#create a readmission column
admit_df['READMISSION'] = 0

# %%
#if the number of readmit days is between 1 and 30, set readmission as 1
admit_df.loc[(admit_df['DAYS_READMIT'] > 0) & (admit_df['DAYS_READMIT'] < 31), 'READMISSION'] = 1

# %%
admit_df['READMISSION'].value_counts()
# Out:
# 0    55782
# 1     3194
# Name: READMISSION, dtype: int64

# %% [markdown]
# ## Grouping Codes by Subject and Admission IDs

# %% [markdown]
# Some of the datasets need to be grouped by subject and admission IDs such as the diagonsis and ICD codes, since each admissions could have multiple codes.

# %%
#group the CPT dataset
cpt_events_df = group_categories(cpt_events_df, 'CPT_CD')

# %%
#group the diagnoses dataset
diagnoses_icd_df = group_categories(diagnoses_icd_df, 'ICD9_CODE')
diagnoses_icd_df.rename(columns={'ICD9_CODE': 'DIAG_ICD9_CODE'}, inplace=True)

# %%
#group the DRG dataset
drg_codes_df = group_categories(drg_codes_df, 'DRG_CODE')

# %%
#group the procedures dataset
proced_icd_df = group_categories(proced_icd_df, 'ICD9_CODE')
proced_icd_df.rename(columns={'ICD9_CODE': 'PROCED_ICD9_CODE'}, inplace=True)

# %% [markdown]
# ## Merging Dataframes

# %% [markdown]
# Here, I merged some of the datasets based on the subject and admissions IDs.

# %% [markdown]
# The modified admissions and PATIENTS datasets can be merged using the subject ID. The PATIENTS dataset has the date of birth (DOB) of the patient, which can be subtracted by the discharge date to get the age of the patient. However, patients who are over 89 years old had their DOB shifted to 300 years after the admission date to comply with HIPAA regulations.

# %%
#merge the modified admissions dataset with the PATIENTS dataset
mod_admit_df = admit_df.merge(patients_df, on='SUBJECT_ID')

# %%
#obtain the year, month, and date of the discharge time
mod_admit_df['DOB'] = mod_admit_df['DOB'].str[:10]

# %%
#review the modified discharge time
mod_admit_df['DISCHTIME']
# Out:
# 0       2100-06-09
# 1       2100-06-19
# 2       2100-06-27
# 3       2100-06-17
# 4       2100-06-30
#            ...
# 58971   2201-08-04
# 58972   2201-08-12
# 58973   2201-11-06
# 58974   2201-11-27
# 58975   2202-03-18
# Name: DISCHTIME, Length: 58976, dtype: datetime64[ns]

# %%
#convert the discharge time and the date of birth into datetime
mod_admit_df['DOB'] = pd.to_datetime(mod_admit_df['DOB'], format="%Y/%m/%d")

# %%
#convert the discharge time and the date of birth to time series
ts_dob = mod_admit_df['DOB'].dt.to_pydatetime()

# %%
#subtract the dischrage time by the date of birth, and divide by 365 to get years
age_df = pd.DataFrame((ts_disch-ts_dob)//365)

# %%
#retrieve the age, but note that because the structure of the datetime data, dt.days will return the int value of whatever is in the columns. Since I
#already divided by 365, when I use dt.days, I am actually getting the years
mod_admit_df['AGE'] = age_df[0].dt.days

# %%
#check the value counts of the age to see how many of the values are 300
mod_admit_df['AGE'].value_counts()
# Out:
# 0      8074
# 300    2607
# 78     1143
# 77     1126
# 69     1104
#        ...
# 306       1
# 91        1
# 305       1
# 301       1
# 7         1
# Name: AGE, Length: 92, dtype: int64

# %% [markdown]
# About 2K admissions were of patients who were older than 89. In order to adjust the number, I assumed that all people ages "300" are 90.

# %%
#change anyone with an age of 300 to 90
mod_admit_df.loc[mod_admit_df['AGE'] == 300, "AGE"] = 90

# %%
mod_admit_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 0       53486       82574   118464 2100-06-07 2100-06-09      EMERGENCY
# 1       35574       29156   161773 2100-06-09 2100-06-19      EMERGENCY
# 2       14753       12001   173927 2100-06-14 2100-06-27      EMERGENCY
# 3       25723       21081   159656 2100-06-14 2100-06-17      EMERGENCY
# 4       38932       32096   158366 2100-06-22 2100-06-30      EMERGENCY
# ...       ...         ...      ...        ...        ...            ...
# 58971   10977        8982   192942 2201-07-24 2201-08-04        NEWBORN
# 58972    9040        7391   153695 2201-07-26 2201-08-12       ELECTIVE
# 58973    9041        7391   135421 2201-08-26 2201-11-06      EMERGENCY
# 58974    9042        7391   112425 2201-11-17 2201-11-27      EMERGENCY
# 58975    9043        7391   121041 2201-12-08 2202-03-18      EMERGENCY
#
#               ADMISSION_LOCATION        DISCHARGE_LOCATION INSURANCE LANGUAGE  \
# 0      CLINIC REFERRAL/PREMATURE                      HOME  Medicaid     ENGL
# 1           EMERGENCY ROOM ADMIT              DEAD/EXPIRED   Private     CANT
# 2           EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 3           EMERGENCY ROOM ADMIT                      HOME  Medicaid      NaN
# 4           EMERGENCY ROOM ADMIT  REHAB/DISTINCT PART HOSP   Private     ENGL
# ...                          ...                       ...       ...      ...
# 58971  CLINIC REFERRAL/PREMATURE       SHORT TERM HOSPITAL   Private      NaN
# 58972  PHYS REFERRAL/NORMAL DELI          HOME HEALTH CARE  Medicare      NaN
# 58973  TRANSFER FROM HOSP/EXTRAM  REHAB/DISTINCT PART HOSP  Medicare      NaN
# 58974       EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 58975       EMERGENCY ROOM ADMIT              DEAD/EXPIRED  Medicare      NaN
#
#        ...               ETHNICITY                                  DIAGNOSIS  \
# 0      ...                   OTHER                                HYPOTENSION
# 1      ...                   WHITE                       RESPIRATORY DISTRESS
# 2      ...                   WHITE                  RT BASAL GANGLIA BLEEDING
# 3      ...  BLACK/AFRICAN AMERICAN                        SHORTNESS OF BREATH
# 4      ...                   WHITE  STERNAL FRACTURE,RIB FRACTURE,LACERATIONS
# ...    ...                     ...                                        ...
# 58971  ...                   WHITE                                    NEWBORN
# 58972  ...                   WHITE   CROHN'S DISEASE; ENTEROCUTANEOUS FISTULA
# 58973  ...                   WHITE                           ABDOMINAL ABCESS
# 58974  ...                   WHITE                                     SEPSIS
# 58975  ...                   WHITE                             ABDOMINAL PAIN
#
#       HAS_CHARTEVENTS_DATA READMITTIME  READMIT_TYPE DAYS_READMIT READMISSION  \
# 0                        1         NaT           NaN       1000.0           0
# 1                        1         NaT           NaN       1000.0           0
# 2                        1         NaT           NaN       1000.0           0
# 3                        1         NaT           NaN       1000.0           0
# 4                        1         NaT           NaN       1000.0           0
# ...                    ...         ...           ...          ...         ...
# 58971                    1         NaT           NaN       1000.0           0
# 58972                    1  2201-08-26     EMERGENCY         14.0           1
# 58973                    1  2201-11-17     EMERGENCY         11.0           1
# 58974                    1  2201-12-08     EMERGENCY         11.0           1
# 58975                    1         NaT           NaN       1000.0           0
#
#        GENDER        DOB AGE
# 0           M 2044-04-23  56
# 1           M 2028-04-23  72
# 2           F 2028-10-27  71
# 3           F 2067-04-01  33
# 4           F 2070-12-13  29
# ...       ...        ...  ..
# 58971       M 2201-07-24   7
# 58972       F 2133-07-08  75
# 58973       F 2133-07-08  76
# 58974       F 2133-07-08  76
# 58975       F 2133-07-08  77
#
# [58976 rows x 22 columns]

# %% [markdown]
# In addition, I merged the CPT,

# %%
#merge the admissions dataframe
main_df = mod_admit_df.merge(notes_df, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
main_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 0       53486       82574   118464 2100-06-07 2100-06-09      EMERGENCY
# 1       35574       29156   161773 2100-06-09 2100-06-19      EMERGENCY
# 2       14753       12001   173927 2100-06-14 2100-06-27      EMERGENCY
# 3       25723       21081   159656 2100-06-14 2100-06-17      EMERGENCY
# 4       38932       32096   158366 2100-06-22 2100-06-30      EMERGENCY
# ...       ...         ...      ...        ...        ...            ...
# 52721   10977        8982   192942 2201-07-24 2201-08-04        NEWBORN
# 52722    9040        7391   153695 2201-07-26 2201-08-12       ELECTIVE
# 52723    9041        7391   135421 2201-08-26 2201-11-06      EMERGENCY
# 52724    9042        7391   112425 2201-11-17 2201-11-27      EMERGENCY
# 52725    9043        7391   121041 2201-12-08 2202-03-18      EMERGENCY
#
#               ADMISSION_LOCATION        DISCHARGE_LOCATION INSURANCE LANGUAGE  \
# 0      CLINIC REFERRAL/PREMATURE                      HOME  Medicaid     ENGL
# 1           EMERGENCY ROOM ADMIT              DEAD/EXPIRED   Private     CANT
# 2           EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 3           EMERGENCY ROOM ADMIT                      HOME  Medicaid      NaN
# 4           EMERGENCY ROOM ADMIT  REHAB/DISTINCT PART HOSP   Private     ENGL
# ...                          ...                       ...       ...      ...
# 52721  CLINIC REFERRAL/PREMATURE       SHORT TERM HOSPITAL   Private      NaN
# 52722  PHYS REFERRAL/NORMAL DELI          HOME HEALTH CARE  Medicare      NaN
# 52723  TRANSFER FROM HOSP/EXTRAM  REHAB/DISTINCT PART HOSP  Medicare      NaN
# 52724       EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 52725       EMERGENCY ROOM ADMIT              DEAD/EXPIRED  Medicare      NaN
#
#        ...                                  DIAGNOSIS HAS_CHARTEVENTS_DATA  \
# 0      ...                                HYPOTENSION                    1
# 1      ...                       RESPIRATORY DISTRESS                    1
# 2      ...                  RT BASAL GANGLIA BLEEDING                    1
# 3      ...                        SHORTNESS OF BREATH                    1
# 4      ...  STERNAL FRACTURE,RIB FRACTURE,LACERATIONS                    1
# ...    ...                                        ...                  ...
# 52721  ...                                    NEWBORN                    1
# 52722  ...   CROHN'S DISEASE; ENTEROCUTANEOUS FISTULA                    1
# 52723  ...                           ABDOMINAL ABCESS                    1
# 52724  ...                                     SEPSIS                    1
# 52725  ...                             ABDOMINAL PAIN                    1
#
#       READMITTIME READMIT_TYPE  DAYS_READMIT READMISSION GENDER        DOB  \
# 0             NaT          NaN        1000.0           0      M 2044-04-23
# 1             NaT          NaN        1000.0           0      M 2028-04-23
# 2             NaT          NaN        1000.0           0      F 2028-10-27
# 3             NaT          NaN        1000.0           0      F 2067-04-01
# 4             NaT          NaN        1000.0           0      F 2070-12-13
# ...           ...          ...           ...         ...    ...        ...
# 52721         NaT          NaN        1000.0           0      M 2201-07-24
# 52722  2201-08-26    EMERGENCY          14.0           1      F 2133-07-08
# 52723  2201-11-17    EMERGENCY          11.0           1      F 2133-07-08
# 52724  2201-12-08    EMERGENCY          11.0           1      F 2133-07-08
# 52725         NaT          NaN        1000.0           0      F 2133-07-08
#
#        AGE                                               TEXT
# 0       56  Admission Date:  [**2100-6-7**]              D...
# 1       72  Admission Date:  [**2100-6-9**]              D...
# 2       71  Admission Date:  [**2100-6-14**]       Dischar...
# 3       33  Admission Date:  [**2100-6-14**]     Discharge...
# 4       29  Admission Date:  [**2100-6-22**]              ...
# ...    ...                                                ...
# 52721    7  Admission Date: [**2201-7-24**]        Dischar...
# 52722   75  Admission Date:  [**2201-7-26**]              ...
# 52723   76  Admission Date:  [**2201-8-26**]              ...
# 52724   76  Admission Date:  [**2201-11-17**]             ...
# 52725   77  Admission Date:  [**2201-12-8**]              ...
#
# [52726 rows x 23 columns]

# %%
print("The modified admissions dataset has", str(len(mod_admit_df)),"rows.")
print("The notes dataset has", str(len(notes_df)),"rows.")
print("The merged dataset has", str(len(main_df)),"rows.")
# Out:
# The modified admissions dataset has 58976 rows.
# The notes dataset has 52726 rows.
# The merged dataset has 52726 rows.

# %% [markdown]
# From this inner merge, about 6K rows were lost. Below I explore where there are null values after doing an 'outer' merge between the admissions and notes datasets.

# %%
#performing outer merge to see where the null values are
main2_df = mod_admit_df.merge(notes_df, on=['SUBJECT_ID', 'HADM_ID'], how='outer')
main2_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 0       53486       82574   118464 2100-06-07 2100-06-09      EMERGENCY
# 1       35574       29156   161773 2100-06-09 2100-06-19      EMERGENCY
# 2       14753       12001   173927 2100-06-14 2100-06-27      EMERGENCY
# 3       25723       21081   159656 2100-06-14 2100-06-17      EMERGENCY
# 4       38932       32096   158366 2100-06-22 2100-06-30      EMERGENCY
# ...       ...         ...      ...        ...        ...            ...
# 58971   10977        8982   192942 2201-07-24 2201-08-04        NEWBORN
# 58972    9040        7391   153695 2201-07-26 2201-08-12       ELECTIVE
# 58973    9041        7391   135421 2201-08-26 2201-11-06      EMERGENCY
# 58974    9042        7391   112425 2201-11-17 2201-11-27      EMERGENCY
# 58975    9043        7391   121041 2201-12-08 2202-03-18      EMERGENCY
#
#               ADMISSION_LOCATION        DISCHARGE_LOCATION INSURANCE LANGUAGE  \
# 0      CLINIC REFERRAL/PREMATURE                      HOME  Medicaid     ENGL
# 1           EMERGENCY ROOM ADMIT              DEAD/EXPIRED   Private     CANT
# 2           EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 3           EMERGENCY ROOM ADMIT                      HOME  Medicaid      NaN
# 4           EMERGENCY ROOM ADMIT  REHAB/DISTINCT PART HOSP   Private     ENGL
# ...                          ...                       ...       ...      ...
# 58971  CLINIC REFERRAL/PREMATURE       SHORT TERM HOSPITAL   Private      NaN
# 58972  PHYS REFERRAL/NORMAL DELI          HOME HEALTH CARE  Medicare      NaN
# 58973  TRANSFER FROM HOSP/EXTRAM  REHAB/DISTINCT PART HOSP  Medicare      NaN
# 58974       EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 58975       EMERGENCY ROOM ADMIT              DEAD/EXPIRED  Medicare      NaN
#
#        ...                                  DIAGNOSIS HAS_CHARTEVENTS_DATA  \
# 0      ...                                HYPOTENSION                    1
# 1      ...                       RESPIRATORY DISTRESS                    1
# 2      ...                  RT BASAL GANGLIA BLEEDING                    1
# 3      ...                        SHORTNESS OF BREATH                    1
# 4      ...  STERNAL FRACTURE,RIB FRACTURE,LACERATIONS                    1
# ...    ...                                        ...                  ...
# 58971  ...                                    NEWBORN                    1
# 58972  ...   CROHN'S DISEASE; ENTEROCUTANEOUS FISTULA                    1
# 58973  ...                           ABDOMINAL ABCESS                    1
# 58974  ...                                     SEPSIS                    1
# 58975  ...                             ABDOMINAL PAIN                    1
#
#       READMITTIME READMIT_TYPE  DAYS_READMIT READMISSION GENDER        DOB  \
# 0             NaT          NaN        1000.0           0      M 2044-04-23
# 1             NaT          NaN        1000.0           0      M 2028-04-23
# 2             NaT          NaN        1000.0           0      F 2028-10-27
# 3             NaT          NaN        1000.0           0      F 2067-04-01
# 4             NaT          NaN        1000.0           0      F 2070-12-13
# ...           ...          ...           ...         ...    ...        ...
# 58971         NaT          NaN        1000.0           0      M 2201-07-24
# 58972  2201-08-26    EMERGENCY          14.0           1      F 2133-07-08
# 58973  2201-11-17    EMERGENCY          11.0           1      F 2133-07-08
# 58974  2201-12-08    EMERGENCY          11.0           1      F 2133-07-08
# 58975         NaT          NaN        1000.0           0      F 2133-07-08
#
#        AGE                                               TEXT
# 0       56  Admission Date:  [**2100-6-7**]              D...
# 1       72  Admission Date:  [**2100-6-9**]              D...
# 2       71  Admission Date:  [**2100-6-14**]       Dischar...
# 3       33  Admission Date:  [**2100-6-14**]     Discharge...
# 4       29  Admission Date:  [**2100-6-22**]              ...
# ...    ...                                                ...
# 58971    7  Admission Date: [**2201-7-24**]        Dischar...
# 58972   75  Admission Date:  [**2201-7-26**]              ...
# 58973   76  Admission Date:  [**2201-8-26**]              ...
# 58974   76  Admission Date:  [**2201-11-17**]             ...
# 58975   77  Admission Date:  [**2201-12-8**]              ...
#
# [58976 rows x 23 columns]

# %%
#reviewing where there is a null for the text value in the merged file from the notes dataset
null_text_df = main2_df[main2_df['TEXT'].isna()]
null_text_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 17      35034       28711   104132 2100-07-02 2100-07-07        NEWBORN
# 19        602         476   161042 2100-07-05 2100-07-07        NEWBORN
# 45      43523       51754   182977 2100-12-22 2100-12-24       ELECTIVE
# 46      33653       27526   134575 2100-07-29 2100-08-03        NEWBORN
# 53       2959        2437   104692 2100-08-03 2100-08-05        NEWBORN
# ...       ...         ...      ...        ...        ...            ...
# 58941   22936       18806   101513 2201-06-10 2201-06-14        NEWBORN
# 58956   13969       11400   109331 2201-06-25 2201-06-27        NEWBORN
# 58961   29635       24254   118562 2201-06-29 2201-07-03        NEWBORN
# 58966   51990       77930   151564 2201-07-14 2201-07-21      EMERGENCY
# 58969   31683       25913   147240 2201-07-17 2201-07-19        NEWBORN
#
#               ADMISSION_LOCATION DISCHARGE_LOCATION INSURANCE LANGUAGE  ...  \
# 17     PHYS REFERRAL/NORMAL DELI               HOME   Private      NaN  ...
# 19     PHYS REFERRAL/NORMAL DELI               HOME   Private      NaN  ...
# 45     PHYS REFERRAL/NORMAL DELI               HOME   Private     ENGL  ...
# 46     PHYS REFERRAL/NORMAL DELI               HOME  Medicaid      NaN  ...
# 53     PHYS REFERRAL/NORMAL DELI               HOME  Medicaid      NaN  ...
# ...                          ...                ...       ...      ...  ...
# 58941  PHYS REFERRAL/NORMAL DELI               HOME   Private      NaN  ...
# 58956  PHYS REFERRAL/NORMAL DELI               HOME   Private      NaN  ...
# 58961  PHYS REFERRAL/NORMAL DELI   HOME HEALTH CARE   Private      NaN  ...
# 58966       EMERGENCY ROOM ADMIT   HOME HEALTH CARE  Medicare     ENGL  ...
# 58969  PHYS REFERRAL/NORMAL DELI               HOME   Private      NaN  ...
#
#                                                DIAGNOSIS HAS_CHARTEVENTS_DATA  \
# 17                                               NEWBORN                    1
# 19                                               NEWBORN                    1
# 45     OBSTRUCTIVE HYPERTROPHIC CARDIOMYOPATHY\ETHANO...                    1
# 46                                               NEWBORN                    1
# 53                                               NEWBORN                    1
# ...                                                  ...                  ...
# 58941                                            NEWBORN                    1
# 58956                                            NEWBORN                    1
# 58961                                            NEWBORN                    1
# 58966                                      AFIB WITH RVR                    1
# 58969                                            NEWBORN                    1
#
#       READMITTIME READMIT_TYPE  DAYS_READMIT READMISSION GENDER        DOB  \
# 17            NaT          NaN        1000.0           0      M 2100-07-02
# 19            NaT          NaN        1000.0           0      F 2100-07-05
# 45            NaT          NaN        1000.0           0      M 2055-07-09
# 46            NaT          NaN        1000.0           0      F 2100-07-29
# 53            NaT          NaN        1000.0           0      M 2100-08-03
# ...           ...          ...           ...         ...    ...        ...
# 58941         NaT          NaN        1000.0           0      F 2201-06-10
# 58956         NaT          NaN        1000.0           0      M 2201-06-25
# 58961         NaT          NaN        1000.0           0      M 2201-06-29
# 58966         NaT          NaN        1000.0           0      F 1901-07-14
# 58969         NaT          NaN        1000.0           0      M 2201-07-17
#
#        AGE TEXT
# 17       0  NaN
# 19       0  NaN
# 45      45  NaN
# 46       0  NaN
# 53       0  NaN
# ...    ...  ...
# 58941    4  NaN
# 58956    5  NaN
# 58961    5  NaN
# 58966  306  NaN
# 58969    6  NaN
#
# [6250 rows x 23 columns]

# %% [markdown]
# It seems like most of the rows that were lost during the merge were because of null discharge notes.

# %%
null_text_df['ADMISSION_TYPE'].value_counts()
# Out:
# NEWBORN      4220
# EMERGENCY    1598
# ELECTIVE      375
# URGENT         57
# Name: ADMISSION_TYPE, dtype: int64

# %% [markdown]
# Based on the admission types, ~4.2K of the rows were newborns and therefore they may not need a discharge summary. I will remove them to explore why the remaining ~1.6K were dropped.

# %%
null_text_df = null_text_df[null_text_df['ADMISSION_TYPE'] != 'NEWBORN']
null_text_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 45      43523       51754   182977 2100-12-22 2100-12-24       ELECTIVE
# 112     44027       53252   189277 2100-09-13 2100-09-13      EMERGENCY
# 155     25392       20801   138996 2100-10-09 2100-10-15      EMERGENCY
# 280     27403       22465   105036 2101-01-02 2101-01-04      EMERGENCY
# 346     33507       27414   111607 2101-02-14 2101-02-15       ELECTIVE
# ...       ...         ...      ...        ...        ...            ...
# 58874   16874       13775   196356 2201-04-18 2201-04-18      EMERGENCY
# 58911   27212       22296   193653 2201-05-22 2201-05-28      EMERGENCY
# 58920    4848        3996   164184 2201-05-27 2201-06-07      EMERGENCY
# 58939   50684       74001   123280 2201-06-10 2201-06-12      EMERGENCY
# 58966   51990       77930   151564 2201-07-14 2201-07-21      EMERGENCY
#
#               ADMISSION_LOCATION         DISCHARGE_LOCATION INSURANCE  \
# 45     PHYS REFERRAL/NORMAL DELI                       HOME   Private
# 112    CLINIC REFERRAL/PREMATURE               DEAD/EXPIRED  Medicare
# 155         EMERGENCY ROOM ADMIT           HOME HEALTH CARE  Medicare
# 280         EMERGENCY ROOM ADMIT  LEFT AGAINST MEDICAL ADVI   Private
# 346    PHYS REFERRAL/NORMAL DELI                       HOME   Private
# ...                          ...                        ...       ...
# 58874       EMERGENCY ROOM ADMIT                       HOME  Self Pay
# 58911       EMERGENCY ROOM ADMIT                       HOME  Medicare
# 58920       EMERGENCY ROOM ADMIT                       HOME  Self Pay
# 58939       EMERGENCY ROOM ADMIT                       HOME  Medicaid
# 58966       EMERGENCY ROOM ADMIT           HOME HEALTH CARE  Medicare
#
#       LANGUAGE  ...                                          DIAGNOSIS  \
# 45        ENGL  ...  OBSTRUCTIVE HYPERTROPHIC CARDIOMYOPATHY\ETHANO...
# 112       ENGL  ...                                          TAMPONADE
# 155        NaN  ...                                       HYPONATREMIA
# 280        NaN  ...                                   S/P 30 FEET FALL
# 346       ENGL  ...                      POPLITEAL ANEURYSM, RIGHT/SDA
# ...        ...  ...                                                ...
# 58874      NaN  ...                                     SKULL FRACTURE
# 58911     HAIT  ...                            INTRACRANIAL HEMORRHAGE
# 58920      NaN  ...                      LIVER LACERATION;PNEUMOTHORAX
# 58939     ENGL  ...                                          PARALYSIS
# 58966     ENGL  ...                                      AFIB WITH RVR
#
#       HAS_CHARTEVENTS_DATA READMITTIME READMIT_TYPE  DAYS_READMIT READMISSION  \
# 45                       1         NaT          NaN        1000.0           0
# 112                      1         NaT          NaN        1000.0           0
# 155                      1  2102-03-10    EMERGENCY         511.0           0
# 280                      1         NaT          NaN        1000.0           0
# 346                      0         NaT          NaN        1000.0           0
# ...                    ...         ...          ...           ...         ...
# 58874                    1         NaT          NaN        1000.0           0
# 58911                    1         NaT          NaN        1000.0           0
# 58920                    1         NaT          NaN        1000.0           0
# 58939                    1  2203-02-26    EMERGENCY         624.0           0
# 58966                    1         NaT          NaN        1000.0           0
#
#       GENDER        DOB  AGE TEXT
# 45         M 2055-07-09   45  NaN
# 112        M 1800-09-13   90  NaN
# 155        F 2036-07-29   64  NaN
# 280        M 2067-09-13   33  NaN
# 346        M 2030-11-26   70  NaN
# ...      ...        ...  ...  ...
# 58874      M 2163-04-09   41  NaN
# 58911      M 2123-05-09   81  NaN
# 58920      M 2177-11-11   27  NaN
# 58939      M 2163-02-03   43  NaN
# 58966      F 1901-07-14  306  NaN
#
# [2030 rows x 23 columns]

# %%
null_text_df['DISCHARGE_LOCATION'].value_counts()
# Out:
# HOME                         1108
# DEAD/EXPIRED                  589
# HOME HEALTH CARE              148
# LEFT AGAINST MEDICAL ADVI      54
# SNF                            40
# REHAB/DISTINCT PART HOSP       20
# DISC-TRAN CANCER/CHLDRN H      19
# SHORT TERM HOSPITAL            19
# LONG TERM CARE HOSPITAL        12
# HOSPICE-HOME                    7
# DISCH-TRAN TO PSYCH HOSP        5
# OTHER FACILITY                  4
# HOSPICE-MEDICAL FACILITY        2
# ICF                             2
# HOME WITH HOME IV PROVIDR       1
# Name: DISCHARGE_LOCATION, dtype: int64

# %% [markdown]
# From the discharge location column, about 600 people were either dead/expired or left against medical advice. This further explains some of the null values in the text columns. The remaining ~1K there may be other reasons, but I am assuming that I can drop these rows for now since there are no discharge notes.

# %% [markdown]
# I merged the CPT, diagnosis, procedure, DRG codes datasets into one dataframe.

# %%
#merge together the four datasets above
merged_df = cpt_events_df.merge(diagnoses_icd_df, on=['SUBJECT_ID', 'HADM_ID'], how='outer')
merged_df = merged_df.merge(drg_codes_df, on=['SUBJECT_ID', 'HADM_ID'], how='outer')
merged_df = merged_df.merge(proced_icd_df, on=['SUBJECT_ID', 'HADM_ID'], how='outer')
merged_df
# Out:
#        SUBJECT_ID  HADM_ID                                    CPT_CD  \
# 0               3   145834                              94003, 94002
# 1               4   185777         99232, 99233, 99238, 99223, 99231
# 2               6   107064  99232, 99233, 99239, 99255, 99291, 99231
# 3               9   150750                                     94003
# 4              11   194540                              99233, 99239
# ...           ...      ...                                       ...
# 58971       99017   103056                                       NaN
# 58972       99088   165352                                       NaN
# 58973       99487   188460                                       NaN
# 58974       99650   190854                                       NaN
# 58975       99903   135939                                       NaN
#
#                                           DIAG_ICD9_CODE   DRG_CODE  \
# 0      78559, 0389, 4280, 2639, 41071, 4254, 4275, 68...        416
# 1      04111, 1363, 5715, 2763, E9317, 042, 7907, V09...        489
# 2       V1582, 2766, 9972, 40391, 2859, 2753, 4440, 2767        302
# 3                      4280, 2765, 4019, 431, 5070, 5849         14
# 4                                                   1913     2, 211
# ...                                                  ...        ...
# 58971                4439, 3659, 41071, 41401, 2859, 496  1742, 247
# 58972                           4019, 72989, 2326, 43889  578, 3611
# 58973  V5867, 41401, 4019, 25000, 2859, 2724, 41021, ...  1742, 247
# 58974  5363, 25040, V4582, 36201, 25060, 3572, 40391,...  554, 1733
# 58975                     V643, 25000, 3051, 74782, 4010    402, 92
#
#                         PROCED_ICD9_CODE
# 0      9604, 8964, 966, 9672, 9962, 3893
# 1                       8872, 3323, 3893
# 2             5569, 9904, 3957, 91, 3806
# 3                             9672, 9604
# 4                   9925, 113, 9229, 159
# ...                                  ...
# 58971             66, 40, 47, 3606, 3607
# 58972                          864, 8661
# 58973       66, 40, 3722, 45, 3607, 8856
# 58974                         3929, 3995
# 58975                               8849
#
# [58976 rows x 6 columns]

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 58976 entries, 0 to 58975
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   SUBJECT_ID        58976 non-null  int64
#  1   HADM_ID           58976 non-null  int64
#  2   CPT_CD            44148 non-null  object
#  3   DIAG_ICD9_CODE    58976 non-null  object
#  4   DRG_CODE          58890 non-null  object
#  5   PROCED_ICD9_CODE  52243 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 3.1+ MB

# %%
#merge in the previously merged dataframe (cpt, diagnosis, procedure, drg codes) with the main_df
main_df = main_df.merge(merged_df, on=['SUBJECT_ID', 'HADM_ID'], how='inner')
main_df
# Out:
#        ROW_ID  SUBJECT_ID  HADM_ID  ADMITTIME  DISCHTIME ADMISSION_TYPE  \
# 0       53486       82574   118464 2100-06-07 2100-06-09      EMERGENCY
# 1       35574       29156   161773 2100-06-09 2100-06-19      EMERGENCY
# 2       14753       12001   173927 2100-06-14 2100-06-27      EMERGENCY
# 3       25723       21081   159656 2100-06-14 2100-06-17      EMERGENCY
# 4       38932       32096   158366 2100-06-22 2100-06-30      EMERGENCY
# ...       ...         ...      ...        ...        ...            ...
# 52721   10977        8982   192942 2201-07-24 2201-08-04        NEWBORN
# 52722    9040        7391   153695 2201-07-26 2201-08-12       ELECTIVE
# 52723    9041        7391   135421 2201-08-26 2201-11-06      EMERGENCY
# 52724    9042        7391   112425 2201-11-17 2201-11-27      EMERGENCY
# 52725    9043        7391   121041 2201-12-08 2202-03-18      EMERGENCY
#
#               ADMISSION_LOCATION        DISCHARGE_LOCATION INSURANCE LANGUAGE  \
# 0      CLINIC REFERRAL/PREMATURE                      HOME  Medicaid     ENGL
# 1           EMERGENCY ROOM ADMIT              DEAD/EXPIRED   Private     CANT
# 2           EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 3           EMERGENCY ROOM ADMIT                      HOME  Medicaid      NaN
# 4           EMERGENCY ROOM ADMIT  REHAB/DISTINCT PART HOSP   Private     ENGL
# ...                          ...                       ...       ...      ...
# 52721  CLINIC REFERRAL/PREMATURE       SHORT TERM HOSPITAL   Private      NaN
# 52722  PHYS REFERRAL/NORMAL DELI          HOME HEALTH CARE  Medicare      NaN
# 52723  TRANSFER FROM HOSP/EXTRAM  REHAB/DISTINCT PART HOSP  Medicare      NaN
# 52724       EMERGENCY ROOM ADMIT                       SNF  Medicare      NaN
# 52725       EMERGENCY ROOM ADMIT              DEAD/EXPIRED  Medicare      NaN
#
#        ... DAYS_READMIT READMISSION GENDER        DOB  AGE  \
# 0      ...       1000.0           0      M 2044-04-23   56
# 1      ...       1000.0           0      M 2028-04-23   72
# 2      ...       1000.0           0      F 2028-10-27   71
# 3      ...       1000.0           0      F 2067-04-01   33
# 4      ...       1000.0           0      F 2070-12-13   29
# ...    ...          ...         ...    ...        ...  ...
# 52721  ...       1000.0           0      M 2201-07-24    7
# 52722  ...         14.0           1      F 2133-07-08   75
# 52723  ...         11.0           1      F 2133-07-08   76
# 52724  ...         11.0           1      F 2133-07-08   76
# 52725  ...       1000.0           0      F 2133-07-08   77
#
#                                                     TEXT  \
# 0      Admission Date:  [**2100-6-7**]              D...
# 1      Admission Date:  [**2100-6-9**]              D...
# 2      Admission Date:  [**2100-6-14**]       Dischar...
# 3      Admission Date:  [**2100-6-14**]     Discharge...
# 4      Admission Date:  [**2100-6-22**]              ...
# ...                                                  ...
# 52721  Admission Date: [**2201-7-24**]        Dischar...
# 52722  Admission Date:  [**2201-7-26**]              ...
# 52723  Admission Date:  [**2201-8-26**]              ...
# 52724  Admission Date:  [**2201-11-17**]             ...
# 52725  Admission Date:  [**2201-12-8**]              ...
#
#                                                 CPT_CD  \
# 0                                  99232, 99291, 99233
# 1      99253, 99291, 99292, 94002, 94003, 99239, 99233
# 2                                                  NaN
# 3                                         99233, 99291
# 4                           27762, 27228, 99254, 27252
# ...                                                ...
# 52721                                              NaN
# 52722                                              NaN
# 52723                                     99232, 99254
# 52724                                              NaN
# 52725                36580, 99251, 99252, 94003, 94002
#
#                                           DIAG_ICD9_CODE         DRG_CODE  \
# 0      7804, 2720, 311, 1985, 28411, V5869, V4589, 24...  2072, 2073, 314
# 1      4821, 53081, 2639, 2859, 49122, 2948, 48241, 5...        1304, 565
# 2          3310, 2720, 7070, 4019, 725, 431, 5990, 29410               14
# 3      30470, 49391, 5070, 9708, E8500, 51881, 96501,...               87
# 4      30470, 8074, 8240, E8230, V4586, 8080, 3051, 8...        9123, 486
# ...                                                  ...              ...
# 52721        V290, 7742, V3001, 76525, 77081, 769, 76516              385
# 52722  5680, 56981, 4019, 25000, 2859, V1279, V442, 9...        148, 2212
# 52723  2752, 0389, 4019, 5362, V552, 99592, 56981, 25...        416, 7204
# 52724  0389, 99592, 56981, 4019, 1122, 5559, 25000, V...        576, 7204
# 52725  4538, 56722, 99859, 4019, 99674, 2536, 5990, 0...          44, 541
#
#                                         PROCED_ICD9_CODE
# 0                                                   9229
# 1                            9604, 966, 9672, 3893, 9915
# 2                                        4513, 966, 4311
# 3                                                    NaN
# 4                7906, 7939, 7909, 390, 9904, 8659, 3893
# ...                                                  ...
# 52721                  9604, 966, 9671, 9390, 9915, 9983
# 52722           4674, 4679, 9904, 4562, 5459, 9915, 4319
# 52723              966, 14, 9904, 3893, 4632, 9915, 8604
# 52724                              9904, 9915, 3893, 966
# 52725  9604, 14, 4623, 5783, 8604, 4639, 4641, 8611, ...
#
# [52726 rows x 27 columns]

# %% [markdown]
# No rows were lost from the main_df (admission and notes combined) after merging with the merged_df (CPT, diagnosis, procedure, DRG codes).

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52726 entries, 0 to 52725
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID                52726 non-null  int64
#  1   SUBJECT_ID            52726 non-null  int64
#  2   HADM_ID               52726 non-null  int64
#  3   ADMITTIME             52726 non-null  datetime64[ns]
#  4   DISCHTIME             52726 non-null  datetime64[ns]
#  5   ADMISSION_TYPE        52726 non-null  object
#  6   ADMISSION_LOCATION    52726 non-null  object
#  7   DISCHARGE_LOCATION    52726 non-null  object
#  8   INSURANCE             52726 non-null  object
#  9   LANGUAGE              32358 non-null  object
#  10  RELIGION              52312 non-null  object
#  11  MARITAL_STATUS        46870 non-null  object
#  12  ETHNICITY             52726 non-null  object
#  13  DIAGNOSIS             52725 non-null  object
#  14  HAS_CHARTEVENTS_DATA  52726 non-null  int64
#  15  READMITTIME           10933 non-null  datetime64[ns]
#  16  READMIT_TYPE          10933 non-null  object
#  17  DAYS_READMIT          52726 non-null  float64
#  18  READMISSION           52726 non-null  int64
#  19  GENDER                52726 non-null  object
#  20  DOB                   52726 non-null  datetime64[ns]
#  21  AGE                   52726 non-null  int64
#  22  TEXT                  52726 non-null  object
#  23  CPT_CD                42701 non-null  object
#  24  DIAG_ICD9_CODE        52726 non-null  object
#  25  DRG_CODE              52715 non-null  object
#  26  PROCED_ICD9_CODE      46841 non-null  object
# dtypes: datetime64[ns](4), float64(1), int64(6), object(16)
# memory usage: 11.3+ MB

# %%
main_df['READMISSION'].value_counts()
# Out:
# 0    49715
# 1     3011
# Name: READMISSION, dtype: int64

# %% [markdown]
# There seems to be some class imbalance between readmissions and no readmissions, but it does not seem to be very high.

# %% [markdown]
# ## Dropping Columns and Handling Missing Values

# %% [markdown]
# Here I drop any irrelevant columns and handle any missinig values.

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52726 entries, 0 to 52725
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ROW_ID                52726 non-null  int64
#  1   SUBJECT_ID            52726 non-null  int64
#  2   HADM_ID               52726 non-null  int64
#  3   ADMITTIME             52726 non-null  datetime64[ns]
#  4   DISCHTIME             52726 non-null  datetime64[ns]
#  5   ADMISSION_TYPE        52726 non-null  object
#  6   ADMISSION_LOCATION    52726 non-null  object
#  7   DISCHARGE_LOCATION    52726 non-null  object
#  8   INSURANCE             52726 non-null  object
#  9   LANGUAGE              32358 non-null  object
#  10  RELIGION              52312 non-null  object
#  11  MARITAL_STATUS        46870 non-null  object
#  12  ETHNICITY             52726 non-null  object
#  13  DIAGNOSIS             52725 non-null  object
#  14  HAS_CHARTEVENTS_DATA  52726 non-null  int64
#  15  READMITTIME           10933 non-null  datetime64[ns]
#  16  READMIT_TYPE          10933 non-null  object
#  17  DAYS_READMIT          52726 non-null  float64
#  18  READMISSION           52726 non-null  int64
#  19  GENDER                52726 non-null  object
#  20  DOB                   52726 non-null  datetime64[ns]
#  21  AGE                   52726 non-null  int64
#  22  TEXT                  52726 non-null  object
#  23  CPT_CD                42701 non-null  object
#  24  DIAG_ICD9_CODE        52726 non-null  object
#  25  DRG_CODE              52715 non-null  object
#  26  PROCED_ICD9_CODE      46841 non-null  object
# dtypes: datetime64[ns](4), float64(1), int64(6), object(16)
# memory usage: 11.3+ MB

# %%
#drop any irrelevant columns
columns_to_drop = ['ROW_ID','SUBJECT_ID','HADM_ID','ADMITTIME','DISCHTIME','HAS_CHARTEVENTS_DATA',
                   'READMITTIME','READMIT_TYPE','DAYS_READMIT','DOB']
main_df.drop(columns_to_drop, axis=1, inplace=True)

# %% [markdown]
# There are missing values in the following columns: LANGUAGE, RELIGION, MARITAL STATUS, DIAGNOSIS, CPT_CD, DRG_CODE, and PROCED_ICD9_CODE. Given that all these columns are categorical columns, I decided to fill all the nulls with "Unknown".

# %%
main_df.fillna("UNKNOWN", inplace=True)

# %%
main_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52726 entries, 0 to 52725
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ADMISSION_TYPE      52726 non-null  object
#  1   ADMISSION_LOCATION  52726 non-null  object
#  2   DISCHARGE_LOCATION  52726 non-null  object
#  3   INSURANCE           52726 non-null  object
#  4   LANGUAGE            52726 non-null  object
#  5   RELIGION            52726 non-null  object
#  6   MARITAL_STATUS      52726 non-null  object
#  7   ETHNICITY           52726 non-null  object
#  8   DIAGNOSIS           52726 non-null  object
#  9   READMISSION         52726 non-null  int64
#  10  GENDER              52726 non-null  object
#  11  AGE                 52726 non-null  int64
#  12  TEXT                52726 non-null  object
#  13  CPT_CD              52726 non-null  object
#  14  DIAG_ICD9_CODE      52726 non-null  object
#  15  DRG_CODE            52726 non-null  object
#  16  PROCED_ICD9_CODE    52726 non-null  object
# dtypes: int64(2), object(15)
# memory usage: 7.2+ MB

# %%
main_df.head()
# Out:
#   ADMISSION_TYPE         ADMISSION_LOCATION        DISCHARGE_LOCATION  \
# 0      EMERGENCY  CLINIC REFERRAL/PREMATURE                      HOME
# 1      EMERGENCY       EMERGENCY ROOM ADMIT              DEAD/EXPIRED
# 2      EMERGENCY       EMERGENCY ROOM ADMIT                       SNF
# 3      EMERGENCY       EMERGENCY ROOM ADMIT                      HOME
# 4      EMERGENCY       EMERGENCY ROOM ADMIT  REHAB/DISTINCT PART HOSP
#
#   INSURANCE LANGUAGE       RELIGION MARITAL_STATUS               ETHNICITY  \
# 0  Medicaid     ENGL       CATHOLIC         SINGLE                   OTHER
# 1   Private     CANT   UNOBTAINABLE        MARRIED                   WHITE
# 2  Medicare  UNKNOWN       CATHOLIC        MARRIED                   WHITE
# 3  Medicaid  UNKNOWN  NOT SPECIFIED         SINGLE  BLACK/AFRICAN AMERICAN
# 4   Private     ENGL  NOT SPECIFIED        MARRIED                   WHITE
#
#                                    DIAGNOSIS  READMISSION GENDER  AGE  \
# 0                                HYPOTENSION            0      M   56
# 1                       RESPIRATORY DISTRESS            0      M   72
# 2                  RT BASAL GANGLIA BLEEDING            0      F   71
# 3                        SHORTNESS OF BREATH            0      F   33
# 4  STERNAL FRACTURE,RIB FRACTURE,LACERATIONS            0      F   29
#
#                                                 TEXT  \
# 0  Admission Date:  [**2100-6-7**]              D...
# 1  Admission Date:  [**2100-6-9**]              D...
# 2  Admission Date:  [**2100-6-14**]       Dischar...
# 3  Admission Date:  [**2100-6-14**]     Discharge...
# 4  Admission Date:  [**2100-6-22**]              ...
#
#                                             CPT_CD  \
# 0                              99232, 99291, 99233
# 1  99253, 99291, 99292, 94002, 94003, 99239, 99233
# 2                                          UNKNOWN
# 3                                     99233, 99291
# 4                       27762, 27228, 99254, 27252
#
#                                       DIAG_ICD9_CODE         DRG_CODE  \
# 0  7804, 2720, 311, 1985, 28411, V5869, V4589, 24...  2072, 2073, 314
# 1  4821, 53081, 2639, 2859, 49122, 2948, 48241, 5...        1304, 565
# 2      3310, 2720, 7070, 4019, 725, 431, 5990, 29410               14
# 3  30470, 49391, 5070, 9708, E8500, 51881, 96501,...               87
# 4  30470, 8074, 8240, E8230, V4586, 8080, 3051, 8...        9123, 486
#
#                           PROCED_ICD9_CODE
# 0                                     9229
# 1              9604, 966, 9672, 3893, 9915
# 2                          4513, 966, 4311
# 3                                  UNKNOWN
# 4  7906, 7939, 7909, 390, 9904, 8659, 3893

# %%
#reviewing what diagnoses were common for patients who were readmitted
readmit_df = main_df[main_df['READMISSION']==1]
readmit_df['DIAGNOSIS'].value_counts().head(10)
# Out:
# PNEUMONIA                   136
# CONGESTIVE HEART FAILURE    106
# SEPSIS                       93
# NEWBORN                      88
# ABDOMINAL PAIN               50
# ALTERED MENTAL STATUS        49
# FEVER                        48
# CHEST PAIN                   48
# GASTROINTESTINAL BLEED       42
# HYPOTENSION                  41
# Name: DIAGNOSIS, dtype: int64

# %% [markdown]
# ## Preprocessing Text Data

# %% [markdown]
# Here I preprocessed the text data by removing line breaks, lowercasing text, and removing punctuations and numbers. I also stem and lemmatize the text.

# %%
#review the first text example to see how to preprocess the text data
main_df['TEXT'][0]
# Out:
# "Admission Date:  [**2100-6-7**]              Discharge Date:   [**2100-6-9**]\n\nDate of Birth:  [**2044-4-23**]             Sex:   M\n\nService: MEDICINE\n\nAllergies:\nNo Known Allergies / Adverse Drug Reactions\n\nAttending:[**First Name3 (LF) 2024**]\nChief Complaint:\ndizziness\n\nMajor Surgical or Invasive Procedure:\nNONE\n\n\nHistory of Present Illness:\nHistory of Present Illness: Mr. [**Known lastname 83415**] is a 56 year old male\nwith PMH notable for metastatic cancer (unknown primary)\nundergoing chemo now presenting with lighheadedness and\nhemoptysis. Pt is undergoing chemo with gemcitabine ([**2100-5-24**],\n[**2100-5-31**]) for malignant neoplasm of unknown primary with multiple\nbone, muscle, and soft-tissue metastases. He came to the\nhospital to start RT to L femur today.  Pt reports a couple days\nof lightheadedness, nonpositional.  Pt reports one episode of\nhemoptysis [**2100-6-3**] but none since then. No sig lung lesions on\nchest CT [**2100-5-27**]. Was scheduled to have transfusion on the day\nof admission. Orthostatics at Dr.[**Name (NI) 83416**] office were Lying BP\n94/52, pulse regular at 64. Standing BP 90/52; pulse 66.  In the\nED, initial VS were: T98, P50, RR16, BP87/43, O2 100% RA. (Per\nDr. [**Last Name (STitle) **] (rad/onc) pt generally has SBP 90s-100s). He received\n5.5L NS (put out 2.5L urine). He was started on Vanc infustion\nbut developed red itchy arm and it was stopped. He was given\nbenadryl with good effect. Pt did receive Cefepime 2g IV. Labs\nnotable for a white count of 2.2, Hct 22.9 (Hct 25 on [**5-31**]).\nChemistries were unremarkable. CXR was clear. CTA showed no PE,\nstable ground glass opacities and lytic lesions. LENIs negative\nfor DVT. On transfer, pt's VS were T 97.6, P62, R16, BP98/59, O2\n99% on RA.  On arrival to the MICU, patient's VS. T98.1, HR68,\nBP101/61, P70, 98%RA.  Pt denies fever, chills, night sweats,\ncough, nausea/vomiting, diarrhea, dysuria. Endorses constipation\nwith last BM two days ago. Denies bloody stool or melena. BP was\nin the 80's systolic. He received 5L of fluid since admission.\n2.5L urine output in the ED. One unit PRBCS was given for\nchronic anemia.  HCT 20.6 on admission, bumped to 24 with the\nunit of blood. CTA ruled out PE. No lung mets but there are\nground glass opacities but similar to prior study 2 wks ago for\nstaging purposes.  Blood cultures were sent.  No fevers.\nBaseline leukopenia. bactrim and keflex for LLE cellulitis, was\nbeing treated prior to admission.\n\n\nPast Medical History:\n1. Hypercholesterolemia.\n2. Tobacco use (30 pack years).\n3. Hypothyroidism.\n4. Asthma.\n5. Depression.\n6. Gastroesophageal reflux.\n7. History of normal stress test.\n8. Recently evaluated by vascular surgery, imaging showed\natherosclerotic plaque in the infrarenal aorta which causes a\nmoderate to moderately severe stenosis.\n9. Recently dx w/HCAP by his PCP, [**8-20**] = day [**4-25**] of\nlevofloxacin.\n.\nPAST SURGICAL HISTORY:\n1. Bilateral inguinal hernia repair.\n2. Umbilical hernia repair.\n3. Epigastric hernia repair.\n4. Endoscopy.\n\nSocial History:\nThe patient used to work in construction and is a facilities\nmanager. Currently disabled. He is able to walk except as\ndescribed above. He uses a cane when necessary. He currently\nsmokes a pack a day and has done so for 30 years. He drinks\nrarely.\n\n\nFamily History:\nThere is a family history of heart disease, diabetes and\nhypercholesterolemia.\n\nPhysical Exam:\nADMISSION PHYSICAL EXAM:\nT98, P50, RR16, BP87/43, O2 100% RA.\nGeneral: Alert, oriented, no acute distress\nCV: Regular rate and rhythm, no m/r/g\nLungs: Clear to auscultation bilaterally, no wheezes, rales,\nronchi\nAbdomen: +BS, soft, non-distended, mild tenderness to palpation,\nno rebound or guarding\nGU: no foley\nExt: Warm, well perfused, 2+ pulses, no clubbing, cyanosis or\nedema\n\nDISCHARGE PHYSICAL EXAM:\nT98.5, P54, RR16, BP 108/75, O2 99% RA.\nGeneral: Alert, oriented, no acute distress\nCV: Regu ...

# %%
#remove line breaks and other formatting text
main_df['TEXT'] = main_df['TEXT'].str.replace('\n',' ')
main_df['TEXT'] = main_df['TEXT'].str.replace('\r',' ')

#remove punctuations and numbers
punc_list = string.punctuation
num_list = '0123456789'
punc_num_list = punc_list + num_list
pun_num_remove = str.maketrans(dict.fromkeys(punc_num_list, " "))
main_df['TEXT'] = main_df['TEXT'].str.translate(pun_num_remove)

#lower case the text
main_df['TEXT'] = main_df['TEXT'].str.lower()

# %%
X = main_df['TEXT']
y = main_df['READMISSION']

# %% [markdown]
# Below, I determined which words are important for indicating readmissions by using a vectorizer and logistic regression, and utilizing the model coefficients. In addition, I did it before stemming and lemmatizing the words.

# %%
sw = stopwords.words('english')

# %%
tfidf = TfidfVectorizer(stop_words=sw)
logreg = LogisticRegression(random_state=42)

# %%
tfidf_fitted = tfidf.fit(X)
tfidf_X = tfidf_fitted.transform(X)
logreg.fit(tfidf_X, y)
# Out:
# LogisticRegression(random_state=42)

# %%
importance = get_most_important_features(tfidf_fitted, logreg, 10)

# %%
top_scores = [a[0] for a in importance[0]['tops']]
top_words = [a[1] for a in importance[0]['tops']]
bottom_scores = [a[0] for a in importance[0]['bottom']]
bottom_words = [a[1] for a in importance[0]['bottom']]

figure = plot_important_words(top_scores, top_words, bottom_scores, bottom_words, "Most Important Words")

# %%
#save the figure in the images folder
figure.savefig('images/Importance.png', bbox_inches='tight')

# %%
#stem the words
main_df['TEXT'] = main_df['TEXT'].apply(stem_text)

# %%
#lemmatize the words
main_df['TEXT'] = main_df['TEXT'].apply(lemmatize_text)

# %%
main_df['TEXT'] = main_df['TEXT'].apply(' '.join)

# %%
main_df['TEXT'][0]
# Out:
# 'admiss date discharg date date of birth sex m servic medicin allergi no known allergi advers drug reaction attend first name lf chief complaint dizzi major surgic or invas procedur none histori of present ill histori of present ill mr known lastnam is a year old male with pmh notabl for metastat cancer unknown primari undergo chemo now present with lighheaded and hemoptysi pt is undergo chemo with gemcitabin for malign neoplasm of unknown primari with multipl bone muscl and soft tissu metastas he came to the hospit to start rt to l femur today pt report a coupl day of lightheaded nonposit pt report one episod of hemoptysi but none sinc then no sig lung lesion on chest ct wa schedul to have transfus on the day of admiss orthostat at dr name ni offic were lie bp pul regular at stand bp pul in the ed initi v were t p rr bp o ra per dr last name stitl rad onc pt gener ha sbp s s he receiv l n put out l urin he wa start on vanc infust but develop red itchi arm and it wa stop he wa given benadryl with good effect pt did receiv cefepim g iv lab notabl for a white count of hct hct on chemistri were unremark cxr wa clear cta show no pe stabl ground glass opac and lytic lesion leni neg for dvt on transfer pt s v were t p r bp o on ra on arriv to the micu patient s v t hr bp p ra pt deni fever chill night sweat cough nausea vomit diarrhea dysuria endors constip with last bm two day ago deni bloodi stool or melena bp wa in the s systol he receiv l of fluid sinc admiss l urin output in the ed one unit prbc wa given for chronic anemia hct on admiss bump to with the unit of blood cta rule out pe no lung met but there are ground glass opac but similar to prior studi wk ago for stage purpos blood cultur were sent no fever baselin leukopenia bactrim and keflex for lle cellul wa be treat prior to admiss past medic histori hypercholesterolemia tobacco use pack year hypothyroid asthma depress gastroesophag reflux histori of normal stress test recent evalu by vascular surgeri imag show atherosclerot plaqu in the infraren aorta which caus a moder to moder sever stenosi recent dx w hcap by hi pcp day of levofloxacin past surgic histori bilater inguin hernia repair umbil hernia repair epigastr hernia repair endoscopi social histori the patient use to work in construct and is a facil manag current disabl he is abl to walk except a describ abov he use a cane when necessari he current smoke a pack a day and ha done so for year he drink rare famili histori there is a famili histori of heart diseas diabet and hypercholesterolemia physic exam admiss physic exam t p rr bp o ra gener alert orient no acut distress cv regular rate and rhythm no m r g lung clear to auscult bilater no wheez rale ronchi abdomen b soft non distend mild tender to palpat no rebound or guard gu no foley ext warm well perfus pul no club cyanosi or edema discharg physic exam t p rr bp o ra gener alert orient no acut distress cv regular rate and rhythm no m r g lung clear to auscult bilater no wheez rale ronchi abdomen b soft non distend mild tender to palpat no rebound or guard gu no foley ext warm well perfus pul no club cyanosi or edema pertin result admiss lab am blood wbc rbc hgb hct mcv mch mchc rdw plt ct am blood neut band lymph mono eo baso atyp meta myelo am blood hypochr anisoci poiklo macroci microci normal polychr normal ovaloci tear dr last name stitl am blood plt smr veri low plt ct am blood glucos urean creat na k cl hco angap am blood calcium mg am blood cortsol pertin lab pm blood hct am blood wbc rbc hgb hct mcv mch mchc rdw plt ct am blood wbc rbc hgb hct mcv mch mchc rdw plt ct am blood plt ct am blood plt ct am blood ret aut am blood glucos urean creat na k cl hco angap am blood alt ast alkpho totbili am blood albumin calcium pho mg iron am blood caltibc ferritn trf am urin color straw appear clear sp last name un am urin blood tr nitrit neg protein neg glucos neg keton neg bilirub neg urobiln neg ph leuk neg am urin rbc wbc bacteri none yeast none epi discharg lab ...

# %% [markdown]
# ## Export Cleaned and Merged Dataset

# %% [markdown]
# Export the cleaned and merged dataset into the data folder.

# %%
#export the main dataframe to the data folder for analysis in the modeling notebook
main_df.to_csv("data/admissions_cleaned.csv.gz",index = False,compression='gzip')
