# %%
import pandas as pd

# %%
diagnoses_icd_df = pd.read_csv('data/DIAGNOSES_ICD.csv.gz', compression='gzip')

# %%
diagnoses_icd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 651047 entries, 0 to 651046
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ROW_ID      651047 non-null  int64
#  1   SUBJECT_ID  651047 non-null  int64
#  2   HADM_ID     651047 non-null  int64
#  3   SEQ_NUM     651000 non-null  float64
#  4   ICD9_CODE   651000 non-null  object
# dtypes: float64(1), int64(3), object(1)
# memory usage: 24.8+ MB

# %%
diagnoses_icd_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM ICD9_CODE
# 0    1297         109   172335      1.0     40301
# 1    1298         109   172335      2.0       486
# 2    1299         109   172335      3.0     58281
# 3    1300         109   172335      4.0      5855
# 4    1301         109   172335      5.0      4254
# 5    1302         109   172335      6.0      2762
# 6    1303         109   172335      7.0      7100
# 7    1304         109   172335      8.0      2767
# 8    1305         109   172335      9.0      7243
# 9    1306         109   172335     10.0     45829

# %%
drg_codes_df = pd.read_csv('data/DRGCODES.csv.gz', compression='gzip')

# %%
drg_codes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 125557 entries, 0 to 125556
# Data columns (total 8 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   ROW_ID         125557 non-null  int64
#  1   SUBJECT_ID     125557 non-null  int64
#  2   HADM_ID        125557 non-null  int64
#  3   DRG_TYPE       125557 non-null  object
#  4   DRG_CODE       125557 non-null  int64
#  5   DESCRIPTION    125494 non-null  object
#  6   DRG_SEVERITY   66634 non-null   float64
#  7   DRG_MORTALITY  66634 non-null   float64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 7.7+ MB

# %%
drg_codes_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID DRG_TYPE  DRG_CODE  \
# 0     342        2491   144486     HCFA        28
# 1     343       24958   162910     HCFA       110
# 2     344       18325   153751     HCFA       390
# 3     345       17887   182692     HCFA        14
# 4     346       11113   157980     HCFA       390
# 5     347       23705   154221     HCFA       385
# 6     348       15787   122380     HCFA       105
# 7     349       13933   194891     HCFA       101
# 8     350       23976   171485     HCFA       107
# 9     351        4351   164767     HCFA        14
#
#                                          DESCRIPTION  DRG_SEVERITY  \
# 0  TRAUMATIC STUPOR & COMA, COMA <1 HR AGE >17 WI...           NaN
# 1  MAJOR CARDIOVASCULAR PROCEDURES WITH COMPLICAT...           NaN
# 2            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
# 3  SPECIFIC CEREBROVASCULAR DISORDERS EXCEPT TRAN...           NaN
# 4            NEONATE WITH OTHER SIGNIFICANT PROBLEMS           NaN
# ...

# %%
drg_codes_df['DRG_TYPE'].value_counts()
# Out:
# APR     66634
# HCFA    31644
# MS      27279
# Name: DRG_TYPE, dtype: int64

# %%
input_cv = pd.read_csv('data/INPUTEVENTS_CV.csv.gz', compression='gzip')
# Out:
# /Users/arthur/opt/anaconda3/envs/main_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (7,9,17,20,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
input_cv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17527935 entries, 0 to 17527934
# Data columns (total 22 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   ROW_ID             int64
#  1   SUBJECT_ID         int64
#  2   HADM_ID            float64
#  3   ICUSTAY_ID         float64
#  4   CHARTTIME          object
#  5   ITEMID             int64
#  6   AMOUNT             float64
#  7   AMOUNTUOM          object
#  8   RATE               float64
#  9   RATEUOM            object
#  10  STORETIME          object
#  11  CGID               float64
#  12  ORDERID            int64
#  13  LINKORDERID        int64
#  14  STOPPED            object
#  15  NEWBOTTLE          float64
#  16  ORIGINALAMOUNT     float64
#  17  ORIGINALAMOUNTUOM  object
#  18  ORIGINALROUTE      object
#  19  ORIGINALRATE       float64
#  20  ORIGINALRATEUOM    object
#  21  ORIGINALSITE       object
# dtypes: float64(8), int64(5), object(9)
# memory usage: 2.9+ GB

# %%
input_cv.head(10)
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  ITEMID  \
# 0     592       24457  184834.0    205776.0  2193-09-11 09:00:00   30056
# 1     593       24457  184834.0    205776.0  2193-09-11 12:00:00   30056
# 2     594       24457  184834.0    205776.0  2193-09-11 16:00:00   30056
# 3     595       24457  184834.0    205776.0  2193-09-11 19:00:00   30056
# 4     596       24457  184834.0    205776.0  2193-09-11 21:00:00   30056
# 5     597       24457  184834.0    205776.0  2193-09-12 09:00:00   30056
# 6     598       24457  184834.0    205776.0  2193-09-12 13:00:00   30056
# 7     599       25177  188419.0    212043.0  2143-09-25 23:00:00   30056
# 8     600       25177  188419.0    212043.0  2143-09-26 11:00:00   30056
# 9     601       25177  188419.0    212043.0  2143-09-26 14:00:00   30056
#
#    AMOUNT AMOUNTUOM  RATE RATEUOM  ...   ORDERID  LINKORDERID  STOPPED  \
# 0   100.0        ml   NaN     NaN  ...    756654      9359133      NaN
# ...

# %%
input_mv = pd.read_csv('data/INPUTEVENTS_MV.csv.gz', compression='gzip')

# %%
input_mv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3618991 entries, 0 to 3618990
# Data columns (total 31 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   ROW_ID                         int64
#  1   SUBJECT_ID                     int64
#  2   HADM_ID                        int64
#  3   ICUSTAY_ID                     float64
#  4   STARTTIME                      object
#  5   ENDTIME                        object
#  6   ITEMID                         int64
#  7   AMOUNT                         float64
#  8   AMOUNTUOM                      object
#  9   RATE                           float64
#  10  RATEUOM                        object
#  11  STORETIME                      object
#  12  CGID                           int64
#  13  ORDERID                        int64
#  14  LINKORDERID                    int64
#  15  ORDERCATEGORYNAME              object
#  16  SECONDARYORDERCATEGORYNAME     object
# ...

# %%
input_mv.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0     241       27063   139787    223259.0  2133-02-05 06:29:00
# 1     242       27063   139787    223259.0  2133-02-05 05:34:00
# 2     243       27063   139787    223259.0  2133-02-05 05:34:00
# 3     244       27063   139787    223259.0  2133-02-03 12:00:00
# 4     245       27063   139787    223259.0  2133-02-03 12:00:00
# 5     246       27063   139787    223259.0  2133-02-05 05:34:00
# 6     247       27063   139787    223259.0  2133-02-05 05:34:00
# 7     248       27063   139787    223259.0  2133-02-05 09:43:00
# 8     249       27063   139787    223259.0  2133-02-05 09:43:00
# 9     250       27063   139787    223259.0  2133-02-05 05:34:00
#
#                ENDTIME  ITEMID      AMOUNT AMOUNTUOM       RATE  ...  \
# 0  2133-02-05 08:45:00  225166    6.774532       mEq        NaN  ...
# 1  2133-02-05 06:30:00  225944   28.132997        ml  30.142497  ...
# ...

# %%
notes_df = pd.read_csv('data/NOTEEVENTS.csv.gz', compression='gzip')
# Out:
# /Users/arthur/opt/anaconda3/envs/main_env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3417: DtypeWarning: Columns (4,5) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
notes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2083180 entries, 0 to 2083179
# Data columns (total 11 columns):
#  #   Column       Dtype
# ---  ------       -----
#  0   ROW_ID       int64
#  1   SUBJECT_ID   int64
#  2   HADM_ID      float64
#  3   CHARTDATE    object
#  4   CHARTTIME    object
#  5   STORETIME    object
#  6   CATEGORY     object
#  7   DESCRIPTION  object
#  8   CGID         float64
#  9   ISERROR      float64
#  10  TEXT         object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 174.8+ MB

# %%
notes_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID   CHARTDATE CHARTTIME STORETIME  \
# 0     174       22532  167853.0  2151-08-04       NaN       NaN
# 1     175       13702  107527.0  2118-06-14       NaN       NaN
# 2     176       13702  167118.0  2119-05-25       NaN       NaN
# 3     177       13702  196489.0  2124-08-18       NaN       NaN
# 4     178       26880  135453.0  2162-03-25       NaN       NaN
# 5     179       53181  170490.0  2172-03-08       NaN       NaN
# 6     180       20646  134727.0  2112-12-10       NaN       NaN
# 7     181       42130  114236.0  2150-03-01       NaN       NaN
# 8     182       56174  163469.0  2118-08-12       NaN       NaN
# 9     183       56174  189681.0  2118-12-09       NaN       NaN
#
#             CATEGORY DESCRIPTION  CGID  ISERROR  \
# 0  Discharge summary      Report   NaN      NaN
# 1  Discharge summary      Report   NaN      NaN
# 2  Discharge summary      Report   NaN      NaN
# 3  Discharge summary      Report   NaN      NaN
# ...

# %%
output_df = pd.read_csv('data/OUTPUTEVENTS.csv.gz', compression='gzip')

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4349218 entries, 0 to 4349217
# Data columns (total 13 columns):
#  #   Column      Dtype
# ---  ------      -----
#  0   ROW_ID      int64
#  1   SUBJECT_ID  int64
#  2   HADM_ID     float64
#  3   ICUSTAY_ID  float64
#  4   CHARTTIME   object
#  5   ITEMID      int64
#  6   VALUE       float64
#  7   VALUEUOM    object
#  8   STORETIME   object
#  9   CGID        int64
#  10  STOPPED     float64
#  11  NEWBOTTLE   float64
#  12  ISERROR     float64
# dtypes: float64(6), int64(4), object(3)
# memory usage: 431.4+ MB

# %%
output_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID   HADM_ID  ICUSTAY_ID            CHARTTIME  ITEMID  \
# 0     344       21219  177991.0    225765.0  2142-09-08 10:00:00   40055
# 1     345       21219  177991.0    225765.0  2142-09-08 12:00:00   40055
# 2     346       21219  177991.0    225765.0  2142-09-08 13:00:00   40055
# 3     347       21219  177991.0    225765.0  2142-09-08 14:00:00   40055
# 4     348       21219  177991.0    225765.0  2142-09-08 16:00:00   40055
# 5     349       21219  177991.0    225765.0  2142-09-08 17:00:00   40055
# 6     350       21219  177991.0    225765.0  2142-09-08 18:00:00   40055
# 7     351       21219  177991.0    225765.0  2142-09-08 20:00:00   40055
# 8     352       21219  177991.0    225765.0  2142-09-08 22:00:00   40055
# 9     353       21219  177991.0    225765.0  2142-09-09 00:00:00   40055
#
#    VALUE VALUEUOM            STORETIME   CGID  STOPPED  NEWBOTTLE  ISERROR
# 0  200.0       ml  2142-09-08 12:08:00  17269      NaN        NaN      NaN
# ...

# %%
proced_events_df = pd.read_csv('data/PROCEDUREEVENTS_MV.csv.gz', compression='gzip')

# %%
proced_events_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258066 entries, 0 to 258065
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   ROW_ID                      258066 non-null  int64
#  1   SUBJECT_ID                  258066 non-null  int64
#  2   HADM_ID                     258066 non-null  int64
#  3   ICUSTAY_ID                  257978 non-null  float64
#  4   STARTTIME                   258066 non-null  object
#  5   ENDTIME                     258066 non-null  object
#  6   ITEMID                      258066 non-null  int64
#  7   VALUE                       258066 non-null  float64
#  8   VALUEUOM                    258066 non-null  object
#  9   LOCATION                    52612 non-null   object
#  10  LOCATIONCATEGORY            52612 non-null   object
#  11  STORETIME                   258066 non-null  object
#  12  CGID                        258066 non-null  int64
# ...

# %%
proced_events_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  ICUSTAY_ID            STARTTIME  \
# 0     379       29070   115071    232563.0  2145-03-12 23:04:00
# 1     380       29070   115071    232563.0  2145-03-12 23:04:00
# 2     381       29070   115071    232563.0  2145-03-12 23:05:00
# 3     382       29070   115071    232563.0  2145-03-12 23:36:00
# 4     383       29070   115071    232563.0  2145-03-13 01:27:00
# 5     384       29070   115071    232563.0  2145-03-13 08:45:00
# 6     385       29070   115071    232563.0  2145-03-13 09:00:00
# 7     386       29070   115071    232563.0  2145-03-14 09:00:00
# 8     387       29070   115071    232563.0  2145-03-14 10:30:00
# 9     388       29070   115071    232563.0  2145-03-15 06:26:00
#
#                ENDTIME  ITEMID   VALUE VALUEUOM  LOCATION  ...  \
# 0  2145-03-12 23:05:00  225401     1.0     None       NaN  ...
# 1  2145-03-12 23:05:00  225454     1.0     None       NaN  ...
# 2  2145-03-18 20:01:00  225792  8456.0     hour       NaN  ...
# ...

# %%
proced_icd_df = pd.read_csv('data/PROCEDURES_ICD.csv.gz', compression='gzip')

# %%
proced_icd_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 240095 entries, 0 to 240094
# Data columns (total 5 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   ROW_ID      240095 non-null  int64
#  1   SUBJECT_ID  240095 non-null  int64
#  2   HADM_ID     240095 non-null  int64
#  3   SEQ_NUM     240095 non-null  int64
#  4   ICD9_CODE   240095 non-null  int64
# dtypes: int64(5)
# memory usage: 9.2 MB

# %%
proced_icd_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID  SEQ_NUM  ICD9_CODE
# 0     944       62641   154460        3       3404
# 1     945        2592   130856        1       9671
# 2     946        2592   130856        2       3893
# 3     947       55357   119355        1       9672
# 4     948       55357   119355        2        331
# 5     949       55357   119355        3       3893
# 6     950        9545   158060        1         34
# 7     951       28600   189217        1       3613
# 8     952       28600   189217        2       3615
# 9     953       28600   189217        3       3961

# %%
services_df = pd.read_csv('data/SERVICES.csv.gz', compression='gzip')

# %%
services_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73343 entries, 0 to 73342
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   ROW_ID        73343 non-null  int64
#  1   SUBJECT_ID    73343 non-null  int64
#  2   HADM_ID       73343 non-null  int64
#  3   TRANSFERTIME  73343 non-null  object
#  4   PREV_SERVICE  14668 non-null  object
#  5   CURR_SERVICE  73343 non-null  object
# dtypes: int64(3), object(3)
# memory usage: 3.4+ MB

# %%
services_df.head(10)
# Out:
#    ROW_ID  SUBJECT_ID  HADM_ID         TRANSFERTIME PREV_SERVICE CURR_SERVICE
# 0     758         471   135879  2122-07-22 14:07:27        TSURG          MED
# 1     759         471   135879  2122-07-26 18:31:49          MED        TSURG
# 2     760         472   173064  2172-09-28 19:22:15          NaN         CMED
# 3     761         473   129194  2201-01-09 20:16:45          NaN           NB
# 4     762         474   194246  2181-03-23 08:24:41          NaN           NB
# 5     763         474   146746  2181-04-04 17:38:46          NaN          NBB
# 6     764         475   139351  2131-09-16 18:44:04          NaN           NB
# 7     765         476   161042  2100-07-05 10:26:45          NaN           NB
# 8     766         477   191025  2156-07-20 11:53:03          NaN          MED
# 9     767         478   137370  2194-07-15 13:55:21          NaN           NB
